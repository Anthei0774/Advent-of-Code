# %% [markdown]
# <a href="https://colab.research.google.com/github/Anthei0774/Advent-of-Code/blob/main/2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # --- Day 1: The Tyranny of the Rocket Equation ---

# %%
with open('1.txt') as f: puzzle = f.read()

puzzle = puzzle.split('\n')
puzzle = list(map(int, puzzle))
puzzle

################################################################################
# PART 1

sum([ fuelRequirement // 3 - 2 for fuelRequirement in puzzle ])

################################################################################
# PART 2

s = 0
for fuelRequirement in puzzle:
    while fuelRequirement != 0:
        fuelRequirement //= 3
        fuelRequirement -= 2
        fuelRequirement = max(fuelRequirement, 0)
        s += fuelRequirement
s
# Out:
# 4994898

# %% [markdown]
# # --- Day 2: 1202 Program Alarm ---

# %%
puzzle = '1,9,10,3,2,3,11,0,99,30,40,50'
with open('2.txt') as f: puzzle = f.read()

puzzle = puzzle.split(',')
puzzle = list(map(int, puzzle))
puzzle

################################################################################
# PART 1

def runIntcode(noun = 12, verb = 2):
    global puzzle

    memory = puzzle.copy()
    memory[1] = noun
    memory[2] = verb

    i = 0
    while True:
        if memory[i] == 99:
            break

        a = memory[ memory[i + 1] ]
        b = memory[ memory[i + 2] ]
        c = memory[i + 3]

        if memory[i] == 1:
            memory[c] = a + b
        if memory[i] == 2:
            memory[c] = a * b

        i += 4
    
    return memory[0]

runIntcode()

################################################################################
# PART 2

found = False

for noun in range(100):
    for verb in range(100):
        output = runIntcode(noun, verb)

        if output == 19690720:
            found = True
            break

    if found: break

100 * noun + verb
# Out:
# 6429

# %% [markdown]
# # --- Day 3: Crossed Wires ---

# %%
puzzle = '''R8,U5,L5,D3
U7,R6,D4,L4'''
puzzle = '''R75,D30,R83,U83,L12,D49,R71,U7,L72
U62,R66,U55,R34,D71,R55,D58,R83'''
puzzle = '''R98,U47,R26,D63,R33,U87,L62,D20,R33,U53,R51
U98,R91,D20,R16,D67,R40,U7,R15,U6,R7'''
with open('3.txt') as f: puzzle = f.read()

puzzle = puzzle.split('\n')
puzzle = [ step.split(',') for step in puzzle ]
puzzle

################################################################################
# PART 1-2

grid = {}

for i in range(2):
    delay = 0

    position = [0, 0]
    for j in range(len(puzzle[i])):
        step = puzzle[i][j]
        direction = None

        if step[0] == 'L': direction = [0, -1]
        if step[0] == 'R': direction = [0, 1]
        if step[0] == 'U': direction = [-1, 0]
        if step[0] == 'D': direction = [1, 0]

        for k in range(int(step[1:])):
            delay += 1

            position[0] += direction[0]
            position[1] += direction[1]

            position = tuple(position)
            if position not in grid:
                grid[position] = { 'wire' : i,
                                   'crossing' : False,
                                   'manhattan' : abs(position[0]) + abs(position[1]),
                                   'delay' : delay}
            else:
                if i != grid[position]['wire']: # only counting collisions with other wire
                    grid[position]['crossing'] = True
                    grid[position]['delay'] += delay
                
            position = list(position)

grid = { position : grid[position] for position in grid if grid[position]['crossing'] }
grid

min( grid[position]['manhattan'] for position in grid if grid[position]['crossing'] ) # part 1

min( grid[position]['delay'] for position in grid if grid[position]['crossing'] ) # part 2
# Out:
# 35194

# %% [markdown]
# # --- Day 4: Secure Container ---

# %%
puzzle = [193651, 649729]

################################################################################
# PART 1

goodPasswords = []

for n in range(puzzle[0], puzzle[1] + 1):

    n = list(str(n))
    n = list(map(int, n))
    
    contains_double = False
    increasing = True

    i = 0
    while i < 5:
        if n[i] == n[i + 1]:
            contains_double = True
        if n[i] > n[i + 1]:
            increasing = False
            break
        i += 1

    if increasing and contains_double: goodPasswords.append(n)
    
len(goodPasswords)

################################################################################
# PART 2

c = 0

for n in goodPasswords:
    digitGroups = [ str(n[0]) ]

    i = 1
    while i < 6:
        current = str(n[i])

        if digitGroups[-1][-1] == current:
            digitGroups[-1] += current
        else:
            digitGroups.append(current)
        i += 1

    digitGroupsLength = [ len(dG) for dG in digitGroups ]
    c += (2 in digitGroupsLength)

c
# Out:
# 1102

# %% [markdown]
# # --- Day 5: Sunny with a Chance of Asteroids ---

# %%
puzzle = '3,0,4,0,99'
puzzle = '1002,4,3,4,33'
puzzle = '1101,100,-1,4,0'
with open('5.txt') as f: puzzle = f.read()

puzzle = puzzle.split(',')
puzzle = list(map(int, puzzle))
puzzle

################################################################################
# PART 1

memory = puzzle.copy()

i = 0
while True:
    if memory[i] == 99:
        break
    cmd = memory[i]
    # print(i, cmd)

    if cmd % 100 in [1, 2]:
        p1_mode = cmd % 1000 // 100
        p2_mode = cmd // 1000
        
        p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
        p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
        
        dst = memory[i + 3]

        if cmd % 100 == 1: memory[ dst ] = p1 + p2
        if cmd % 100 == 2: memory[ dst ] = p1 * p2

        i += 4
        continue
    
    if cmd % 100 in [3, 4]:
        dst = memory[i + 1]

        if cmd % 100 == 3: memory[dst] = 1
        if cmd % 100 == 4: print(memory[dst])

        i += 2
        continue


################################################################################
# PART 2

memory = puzzle.copy()

i = 0
while True:
    if memory[i] == 99:
        break

    cmd = memory[i]
    p1_mode = cmd % 1000 // 100
    p2_mode = cmd // 1000
    # print(i, cmd)

    if cmd % 100 in [1, 2]: # add, multiply    
        p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
        p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
        
        dst = memory[i + 3]

        if cmd % 100 == 1: memory[ dst ] = p1 + p2
        if cmd % 100 == 2: memory[ dst ] = p1 * p2

        i += 4
        continue

    if cmd % 100 in [3, 4]: # input, output
        dst = memory[i + 1]

        if cmd % 100 == 3: memory[dst] = 5
        if cmd % 100 == 4: print(memory[dst])

        i += 2
        continue

    if cmd % 100 in [5, 6]: # jump-if-true, jump-if-false
        p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
        p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]

        if cmd % 100 == 5: i = p2 if p1 != 0 else i + 3 
        if cmd % 100 == 6: i = p2 if p1 == 0 else i + 3 
        continue

    if cmd % 100 in [7, 8]: # less than, equals
        p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
        p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
        dst = memory[i + 3]
        if cmd % 100 == 7: memory[dst] = p1 < p2
        if cmd % 100 == 8: memory[dst] = p1 == p2
        i += 4
        continue
# Out:
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 11049715
# 2140710

# %% [markdown]
# # --- Day 6: Universal Orbit Map ---

# %%
puzzle = '''COM)B
B)C
C)D
D)E
E)F
B)G
G)H
D)I
E)J
J)K
K)L'''
puzzle += '''
K)YOU
I)SAN'''
with open('6.txt') as f: puzzle = f.read()

puzzle = puzzle.split('\n')
puzzle = [ objectPair.split(')') for objectPair in puzzle ]
puzzle

################################################################################
# PART 1

orbits = {}
for orb in puzzle:
    if orb[0] not in orbits:
        orbits[ orb[0] ] = { 'children' : [ orb[1] ]}
    else:
        orbits[ orb[0] ]['children'].append( orb[1] )
    if orb[1] not in orbits:
        orbits[ orb[1] ] = { 'children' : [] }
orbits


currentOrbits = ['COM']
d = 0
s = 0
while currentOrbits != []:

    s += d * len(currentOrbits)

    nextOrbits = []
    for orb in currentOrbits:
        orbits[orb]['depth'] = d
        nextOrbits += orbits[orb]['children']
    
    currentOrbits = nextOrbits.copy()
    d += 1

s

################################################################################
# PART 2

def allDescendants(o):
    global orbits
    D = orbits[o]['children'].copy()
    for c in orbits[o]['children']:
        D += allDescendants(c)
    return D


# 
current = 'YOU'
while True:
    parent = [ orb for orb in orbits if current in orbits[orb]['children'] ]
    assert len(parent) == 1

    parent = parent[0]
    children = allDescendants(parent)
    if 'SAN' in children:
        break
    else:
        current = parent

orbits['YOU']['depth'] + orbits['SAN']['depth'] - 2 * orbits[parent]['depth'] - 2
# Out:
# 304

# %% [markdown]
# # --- Day 7: Amplification Circuit ---

# %%
# part 1 inputs
puzzle = '3,15,3,16,1002,16,10,16,1,16,15,15,4,15,99,0,0'
puzzle = '3,23,3,24,1002,24,10,24,1002,23,-1,23,101,5,23,23,1,24,23,23,4,23,99,0,0'
puzzle = '3,31,3,32,1002,32,10,32,1001,31,-2,31,1007,31,0,33,1002,33,7,33,1,33,31,31,1,32,31,31,4,31,99,0,0,0'

# part 2 inputs
puzzle = '3,26,1001,26,-4,26,3,27,1002,27,2,27,1,27,26,27,4,27,1001,28,-1,28,1005,28,6,99,0,0,5'
puzzle = '3,52,1001,52,-5,52,3,53,1,52,56,54,1007,54,5,55,1005,55,26,1001,54,-5,54,1105,1,12,1,53,54,53,1008,54,0,55,1001,55,1,55,2,53,55,53,4,53,1001,56,-1,56,1005,56,6,99,0,0,0,0,10'
with open('7.txt') as f: puzzle = f.read()

puzzle = puzzle.split(',')
puzzle = list(map(int, puzzle))
puzzle

################################################################################
# PART 1

from itertools import permutations
perms = permutations(range(5))
perms = [ p for p in perms ]
perms


S = 0
P = None
for p in perms:
    signal = 0
    

    for phaseSetting in p:
        usePhaseSetting = True

        # running intcode-program here
        memory = puzzle.copy()
        i = 0
        while True:
            if memory[i] == 99:
                break

            cmd = memory[i]
            p1_mode = cmd % 1000 // 100
            p2_mode = cmd // 1000
            # print(i, cmd)

            if cmd % 100 in [1, 2]: # add, multiply    
                p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
                p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
                
                dst = memory[i + 3]

                if cmd % 100 == 1: memory[ dst ] = p1 + p2
                if cmd % 100 == 2: memory[ dst ] = p1 * p2

                i += 4
                continue

            if cmd % 100 in [3, 4]: # input, output
                dst = memory[i + 1]

                if cmd % 100 == 3:
                    if usePhaseSetting:
                        memory[dst] = phaseSetting
                        usePhaseSetting = False # use phase settings only once
                    else:
                        memory[dst] = signal
                        usePhaseSetting = True # reset for the next thruster
                if cmd % 100 == 4: signal = memory[dst]

                i += 2
                continue

            if cmd % 100 in [5, 6]: # jump-if-true, jump-if-false
                p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
                p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]

                if cmd % 100 == 5: i = p2 if p1 != 0 else i + 3 
                if cmd % 100 == 6: i = p2 if p1 == 0 else i + 3 
                continue

            if cmd % 100 in [7, 8]: # less than, equals
                p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
                p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
                dst = memory[i + 3]
                if cmd % 100 == 7: memory[dst] = p1 < p2
                if cmd % 100 == 8: memory[dst] = p1 == p2
                i += 4
                continue

    if S < signal:
        S = signal
        P = p
S, P

################################################################################
# PART 2

from time import sleep

perms = permutations(range(5, 10))
perms = [ p for p in perms ]
perms


S = 0
P = None
for p in perms:
    # print('Current permutation:', p)

    # init thrusters for each permutation, each has its on phase setting, index and halting indicator
    thrusters = {
        'A': { 'memory' : puzzle.copy(), 'phaseSetting' : p[0], 'usePhaseSetting' : True, 'i' : 0, 'next' : 'B', 'halting' : False },
        'B': { 'memory' : puzzle.copy(), 'phaseSetting' : p[1], 'usePhaseSetting' : True, 'i' : 0, 'next' : 'C', 'halting' : False },
        'C': { 'memory' : puzzle.copy(), 'phaseSetting' : p[2], 'usePhaseSetting' : True, 'i' : 0, 'next' : 'D', 'halting' : False },
        'D': { 'memory' : puzzle.copy(), 'phaseSetting' : p[3], 'usePhaseSetting' : True, 'i' : 0, 'next' : 'E', 'halting' : False },
        'E': { 'memory' : puzzle.copy(), 'phaseSetting' : p[4], 'usePhaseSetting' : True, 'i' : 0, 'next' : 'A', 'halting' : False }
    }

    currentThruster = 'A'
    i = 0
    memory = puzzle.copy()

    signal = 0

    # feedback loop
    while True:
        if thrusters['E']['halting']: break

        # thruster loop
        while True:
            if thrusters[currentThruster]['halting']: break

            if memory[i] == 99:
                thrusters[currentThruster]['halting'] = True
                # print('Thruster', currentThruster, 'is now halting.')
                break

            cmd = memory[i]
            p1_mode = cmd % 1000 // 100
            p2_mode = cmd // 1000
            # print(i, cmd)

            if cmd % 100 in [1, 2]: # add, multiply    
                p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
                p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
                
                dst = memory[i + 3]

                if cmd % 100 == 1: memory[ dst ] = p1 + p2
                if cmd % 100 == 2: memory[ dst ] = p1 * p2

                i += 4
                continue

            # modifying input-output handling due to feedback loop
            if cmd % 100 in [3, 4]: # input, output
                dst = memory[i + 1]

                if cmd % 100 == 3:
                    if thrusters[currentThruster]['usePhaseSetting']: # use phase settings only once
                        thrusters[currentThruster]['usePhaseSetting'] = False
                        memory[dst] = thrusters[currentThruster]['phaseSetting']
                    else:
                        memory[dst] = signal # pass signal left and right
                    
                    i += 2
                    continue

                if cmd % 100 == 4:

                    # save signal and memory
                    signal = memory[dst]
                    thrusters[currentThruster]['memory'] = memory.copy()

                    # step with index, save and break out
                    i += 2
                    thrusters[currentThruster]['i'] = i
                    break
        

            if cmd % 100 in [5, 6]: # jump-if-true, jump-if-false
                p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
                p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]

                if cmd % 100 == 5:
                    i = p2 if p1 != 0 else i + 3 
                if cmd % 100 == 6: i = p2 if p1 == 0 else i + 3 
                continue

            if cmd % 100 in [7, 8]: # less than, equals
                p1 = memory[i + 1] if p1_mode else memory[ memory[i + 1] ]
                p2 = memory[i + 2] if p2_mode else memory[ memory[i + 2] ]
                dst = memory[i + 3]
                if cmd % 100 == 7: memory[dst] = p1 < p2
                if cmd % 100 == 8: memory[dst] = p1 == p2
                i += 4
                continue
        
        # if breaking out of the the single thruster loop
        # switch thruster and reset
        currentThruster = thrusters[currentThruster]['next']
        i = thrusters[currentThruster]['i']
        memory = thrusters[currentThruster]['memory'].copy()

    if S < signal:
        S = signal
        P = p

S, P
# Out:
# (36384144, (7, 6, 5, 8, 9))

# %% [markdown]
# # --- Day 8: Space Image Format ---

# %%
puzzle = '123456789012'
W = 3
H = 2

puzzle = '0222112222120000'
W = 2
H = 2

with open('8.txt') as f:
    puzzle = f.read()
    W = 25
    H = 6

puzzle = list(puzzle)
puzzle = list(map(int, puzzle))

import numpy as np
puzzle = np.array(puzzle)
puzzle = puzzle.reshape((-1, H, W))
puzzle

################################################################################
# PART 1

C = np.prod(puzzle.shape)
L = None
for layer in puzzle:
    c = np.sum(layer == 0)
    if c < C:
        C = c
        L = layer

np.sum(L == 1) * np.sum(L == 2)

################################################################################
# PART 2

N = len(puzzle)
N

image = np.zeros((H, W), dtype = int) # init the image black

for i in range(H):
    for j in range(W):

        tmp = list(puzzle[:, i, j])
        
        if 1 in tmp: # if contains white, check if it contains black, then compare
            if 0 not in tmp:
                image[i, j] = 1
            else:
                if tmp.index(1) < tmp.index(0):
                    image[i, j] = 1

from matplotlib import pyplot as plt
plt.imshow(image)

# %% [markdown]
# # --- Day 9: Sensor Boost ---

# %%
puzzle = '109,1,204,-1,1001,100,1,100,1008,100,16,101,1006,101,0,99'
puzzle = '1102,34915192,34915192,7,4,7,99,0'
puzzle = '104,1125899906842624,99'

with open('9.txt') as f:
    puzzle = f.read()

puzzle = puzzle.split(',')
puzzle = list(map(int, puzzle))
puzzle = { i : integer for i, integer in enumerate(puzzle) }
puzzle

################################################################################
# PART 1

# code copied from day 5, modifying parameter handling accordingly

memory = puzzle.copy()

b = 0
i = 0
while True:
    if memory[i] == 99:
        break
    cmd = memory[i]
    # print(i, cmd)

    p1_mode = cmd % 1000 // 100
    p2_mode = cmd % 10000 // 1000
    p3_mode = cmd // 10000
    assert p3_mode != 1

    if cmd % 100 in [1, 2]: # add, multiply
        if p1_mode == 0: p1 = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
        if p1_mode == 1: p1 = memory[i + 1]
        if p1_mode == 2: p1 = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]

        if p2_mode == 0: p2 = 0 if memory[i + 2] not in memory else memory[ memory[i + 2] ]
        if p2_mode == 1: p2 = memory[i + 2]
        if p2_mode == 2: p2 = 0 if b + memory[i + 2] not in memory else memory[b + memory[i + 2]]
        
        if p3_mode == 0: dst = memory[i + 3]
        if p3_mode == 2: dst = b + memory[i + 3]

        if cmd % 100 == 1: memory[dst] = p1 + p2
        if cmd % 100 == 2: memory[dst] = p1 * p2

        i += 4
        continue


    if cmd % 100 in [3, 4, 9]: # input, output, adjust relative base

        if cmd % 100 == 3:
            if p1_mode == 0: dst = memory[i + 1]
            if p1_mode == 2: dst = b + memory[i + 1]
            memory[dst] = 1 # The BOOST program will ask for a single input; run it in test mode by providing it the value 1.
            memory[dst] = 2 # The program runs in sensor boost mode by providing the input instruction the value 2

        if cmd % 100 in [4, 9]:
            if p1_mode == 0: val = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
            if p1_mode == 1: val = memory[i + 1]
            if p1_mode == 2: val = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]
            
            if cmd % 100 == 4: print(val)
            if cmd % 100 == 9: b += val

        i += 2
        continue

    if cmd % 100 in [5, 6]: # jump-if-true, jump-if-false
        if p1_mode == 0: p1 = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
        if p1_mode == 1: p1 = memory[i + 1]
        if p1_mode == 2: p1 = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]

        if p2_mode == 0: p2 = 0 if memory[i + 2] not in memory else memory[ memory[i + 2] ]
        if p2_mode == 1: p2 = memory[i + 2]
        if p2_mode == 2: p2 = 0 if b + memory[i + 2] not in memory else memory[b + memory[i + 2]]

        if cmd % 100 == 5: i = p2 if p1 != 0 else i + 3 
        if cmd % 100 == 6: i = p2 if p1 == 0 else i + 3 
        continue

    if cmd % 100 in [7, 8]: # less than, equals
        if p1_mode == 0: p1 = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
        if p1_mode == 1: p1 = memory[i + 1]
        if p1_mode == 2: p1 = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]

        if p2_mode == 0: p2 = 0 if memory[i + 2] not in memory else memory[ memory[i + 2] ]
        if p2_mode == 1: p2 = memory[i + 2]
        if p2_mode == 2: p2 = 0 if b + memory[i + 2] not in memory else memory[b + memory[i + 2]]
        
        if p3_mode == 0: dst = memory[i + 3]
        if p3_mode == 2: dst = b + memory[i + 3]

        if cmd % 100 == 7: memory[dst] = p1 < p2
        if cmd % 100 == 8: memory[dst] = p1 == p2
        i += 4
        continue

# FUCK YEAH, INTCODE!
# Out:
# 81348

# %% [markdown]
# # --- Day 10: Monitoring Station ---

# %%
puzzle = '''.#..#
.....
#####
....#
...##'''

puzzle = '''......#.#.
#..#.#....
..#######.
.#.#.###..
.#..#.....
..#....#.#
#..#....#.
.##.#..###
##...#..#.
.#....####'''

puzzle = '''#.#...#.#.
.###....#.
.#....#...
##.#.#.#.#
....#.#.#.
.##..###.#
..#...##..
..##....##
......#...
.####.###.'''

puzzle = '''.#..#..###
####.###.#
....###.#.
..###.##.#
##.##.#.#.
....###..#
..#.#..#.#
#..#.#.###
.##...##.#
.....#.#..'''

puzzle = '''.#..##.###...#######
##.############..##.
.#.######.########.#
.###.#######.####.#.
#####.##.#.##.###.##
..#####..#.#########
####################
#.####....###.#.#.##
##.#################
#####.##.###..####..
..######..##.#######
####.##.####...##..#
.#####..#.######.###
##...#.##########...
#.##########.#######
.####.#.###.###.#.##
....##.##.###..#####
.#.#.###########.###
#.#.#.#####.####.###
###.##.####.##.#..##'''

puzzle = '''.#....#####...#..
##...##.#####..##
##...#...#.#####.
..#.....#...###..
..#.#.....#....##'''

with open('10.txt') as f: puzzle = f.read()

puzzle

################################################################################
# PART 1

import numpy as np

asteroids = {}
r = 0
c = 0
for char in puzzle:
    if char in ['.', '#']:
        if char == '#': asteroids[ (r, c) ] = []
        c += 1
        continue
    if char == '\n':
        r += 1
        c = 0
        continue
asteroids


#
from math import gcd


for i, a1 in enumerate(asteroids):
    for j, a2 in enumerate(asteroids):
        if i + 1 <= j:

            # direction from a1 to a2
            dir = (a2[0] - a1[0], a2[1] - a1[1])

            # normalization
            s = gcd(dir[0], dir[1])
            dir = (dir[0] // s, dir[1] // s)
        
            pos = a1
            while True:
                pos = (pos[0] + dir[0], pos[1] + dir[1])

                if pos in asteroids:
                    break

            if pos == a2:
                asteroids[a1].append(a2)
                asteroids[a2].append(a1)


R = max([ len(asteroids[a]) for a in asteroids ])
A = [ a for a in asteroids if len(asteroids[a]) == R ]
assert len(A) == 1
A = A[0]
A

################################################################################
# PART 2

from math import hypot, atan2, pi


asteroids[A]

# https://stackoverflow.com/questions/41855695/sorting-list-of-two-dimensional-coordinates-by-clockwise-angle-using-python
def clockwise_angl_dist(a):
    global A

    ref = (-1, 0)

    # vector between point and the origin: v = a - A
    # get length and normalize
    v = (a[0] - A[0], a[1] - A[1])
    l = hypot(v[0], v[1])
    v_n = (v[0] / l, v[1] / l)
    

    dotprod  = v_n[0]*ref[0] + v_n[1]*ref[1]     # x1*x2 + y1*y2
    diffprod = ref[1]*v_n[0] - ref[0]*v_n[1]     # x1*y2 - y1*x2
    angl = atan2(diffprod, dotprod)
    # Negative angles represent counter-clockwise angles so we need to subtract them 
    # from 2*pi (360 degrees)
    if angl < 0:
        return 2 * pi + angl, l
    # I return first the angle because that's the primary sorting criterium
    # but if two vectors have the same angle then the shorter distance should come first.
    return angl, l

asteroids[A] = sorted(asteroids[A], key = clockwise_angl_dist)
assert len(asteroids[A]) >= 200

A = asteroids[A][200 - 1]
A[1] * 100 + A[0]

# %% [markdown]
# # --- Day 11: Space Police ---

# %%
with open('11.txt') as f: puzzle = f.read()
puzzle = puzzle.split(',')
puzzle = { i : int(integer) for i, integer in enumerate(puzzle) }
puzzle

################################################################################
# PART 1

# code copied from day 9, modifying outputs

memory = puzzle.copy()
b = 0
i = 0
halting = False

iter = 0
pos = (0, 0)
dir = (0, 1)
activePanels = []
L = 0

while not halting:

    paintOutput = None
    turnOutput = None

    while True:
        if halting: break
        if memory[i] == 99:
            halting = True
            break
        cmd = memory[i]
        # print(i, cmd)

        p1_mode = cmd % 1000 // 100
        p2_mode = cmd % 10000 // 1000
        p3_mode = cmd // 10000
        assert p3_mode != 1

        if cmd % 100 in [1, 2]: # add, multiply
            if p1_mode == 0: p1 = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
            if p1_mode == 1: p1 = memory[i + 1]
            if p1_mode == 2: p1 = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]

            if p2_mode == 0: p2 = 0 if memory[i + 2] not in memory else memory[ memory[i + 2] ]
            if p2_mode == 1: p2 = memory[i + 2]
            if p2_mode == 2: p2 = 0 if b + memory[i + 2] not in memory else memory[b + memory[i + 2]]
            
            if p3_mode == 0: dst = memory[i + 3]
            if p3_mode == 2: dst = b + memory[i + 3]

            if cmd % 100 == 1: memory[dst] = p1 + p2
            if cmd % 100 == 2: memory[dst] = p1 * p2

            i += 4
            continue


        if cmd % 100 in [3, 4, 9]: # input, output, adjust relative base

            if cmd % 100 == 3:
                if p1_mode == 0: dst = memory[i + 1]
                if p1_mode == 2: dst = b + memory[i + 1] 
                memory[dst] = 1 if pos in activePanels else 0 # provide 0 if the robot is over a black panel or 1 if the robot is over a white panel
                i += 2
                continue

            if cmd % 100 in [4, 9]:
                if p1_mode == 0: val = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
                if p1_mode == 1: val = memory[i + 1]
                if p1_mode == 2: val = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]
                
                if cmd % 100 == 4:
                    i += 2
                    if paintOutput == None:
                        paintOutput = val
                    else:
                        turnOutput = val
                        break

                if cmd % 100 == 9:
                    b += val
                    i += 2
                    continue

            

        if cmd % 100 in [5, 6]: # jump-if-true, jump-if-false
            if p1_mode == 0: p1 = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
            if p1_mode == 1: p1 = memory[i + 1]
            if p1_mode == 2: p1 = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]

            if p2_mode == 0: p2 = 0 if memory[i + 2] not in memory else memory[ memory[i + 2] ]
            if p2_mode == 1: p2 = memory[i + 2]
            if p2_mode == 2: p2 = 0 if b + memory[i + 2] not in memory else memory[b + memory[i + 2]]

            if cmd % 100 == 5: i = p2 if p1 != 0 else i + 3 
            if cmd % 100 == 6: i = p2 if p1 == 0 else i + 3 
            continue

        if cmd % 100 in [7, 8]: # less than, equals
            if p1_mode == 0: p1 = 0 if memory[i + 1] not in memory else memory[ memory[i + 1] ]
            if p1_mode == 1: p1 = memory[i + 1]
            if p1_mode == 2: p1 = 0 if b + memory[i + 1] not in memory else memory[b + memory[i + 1]]

            if p2_mode == 0: p2 = 0 if memory[i + 2] not in memory else memory[ memory[i + 2] ]
            if p2_mode == 1: p2 = memory[i + 2]
            if p2_mode == 2: p2 = 0 if b + memory[i + 2] not in memory else memory[b + memory[i + 2]]
            
            if p3_mode == 0: dst = memory[i + 3]
            if p3_mode == 2: dst = b + memory[i + 3]

            if cmd % 100 == 7: memory[dst] = p1 < p2
            if cmd % 100 == 8: memory[dst] = p1 == p2
            i += 4
            continue

    iter += 1
    paintOutput = '#' if paintOutput == 0 else '.'
    turnOutput = 'L' if turnOutput == 0 else 'R'
    print('Iter:', iter, '; paint:', paintOutput, '; turn:', turnOutput)

    if paintOutput == '#':
        if pos not in activePanels:
            activePanels.append(pos)
            l = len(activePanels)
            if L < l:
                L = l
    else:
        if pos in activePanels:
            activePanels.remove(pos)

    if turnOutput == 'L':
        dir = (-dir[1], dir[0])
    else:
        dir = (dir[1], -dir[0])

    pos = (pos[0] + dir[0], pos[1] + dir[1])
    

L
# Out:
# Iter: 1 ; paint: . ; turn: L
# Iter: 2 ; paint: . ; turn: R
# Iter: 3 ; paint: . ; turn: L
# Iter: 4 ; paint: . ; turn: L
# Iter: 5 ; paint: . ; turn: R
# Iter: 6 ; paint: . ; turn: L
# Iter: 7 ; paint: . ; turn: R
# Iter: 8 ; paint: . ; turn: R
# Iter: 9 ; paint: . ; turn: R
# Iter: 10 ; paint: . ; turn: L
# Iter: 11 ; paint: . ; turn: L
# Iter: 12 ; paint: . ; turn: R
# Iter: 13 ; paint: . ; turn: R
# Iter: 14 ; paint: . ; turn: R
# Iter: 15 ; paint: . ; turn: R
# Iter: 16 ; paint: . ; turn: R
# Iter: 17 ; paint: . ; turn: R
# Iter: 18 ; paint: . ; turn: R
# Iter: 19 ; paint: . ; turn: R
# Iter: 20 ; paint: . ; turn: R
# Iter: 21 ; paint: . ; turn: R
# Iter: 22 ; paint: . ; turn: R
# Iter: 23 ; paint: . ; turn: R
# Iter: 24 ; paint: . ; turn: R
# Iter: 25 ; paint: . ; turn: R
# Iter: 26 ; paint: . ; turn: R
# Iter: 27 ; paint: . ; turn: R
# Iter: 28 ; paint: . ; turn: R
# Iter: 29 ; paint: . ; turn: R
# Iter: 30 ; paint: . ; turn: R
# Iter: 31 ; paint: . ; turn: R
# Iter: 32 ; paint: . ; turn: R
# Iter: 33 ; paint: . ; turn: R
# Iter: 34 ; paint: . ; turn: R
# Iter: 35 ; paint: . ; turn: R
# Iter: 36 ; paint: . ; turn: R
# Iter: 37 ; paint: . ; turn: R
# Iter: 38 ; paint: . ; turn: R
# Iter: 39 ; paint: . ; turn: R
# Iter: 40 ; paint: . ; turn: R
# Iter: 41 ; paint: . ; turn: R
# Iter: 42 ; paint: . ; turn: R
# Iter: 43 ; paint: . ; turn: R
# Iter: 44 ; paint: . ; turn: R
# Iter: 45 ; paint: . ; turn: R
# Iter: 46 ; paint: . ; turn: R
# Iter: 47 ; paint: . ; turn: R
# Iter: 48 ; paint: . ; turn: R
# Iter: 49 ; paint: . ; turn: R
# Iter: 50 ; paint: . ; turn: R
# Iter: 51 ; paint: . ; turn: R
# Iter: 52 ; paint: . ; turn: R
# Iter: 53 ; paint: . ; turn: R
# Iter: 54 ; paint: . ; turn: R
# Iter: 55 ; paint: . ; turn: R
# Iter: 56 ; paint: . ; turn: R
# Iter: 57 ; paint: . ; turn: R
# Iter: 58 ; paint: . ; turn: R
# Iter: 59 ; paint: . ; turn: R
# Iter: 60 ; paint: . ; turn: R
# Iter: 61 ; paint: . ; turn: R
# Iter: 62 ; paint: . ; turn: R
# Iter: 63 ; paint: . ; turn: R
# Iter: 64 ; paint: . ; turn: R
# Iter: 65 ; paint: . ; turn: R
# Iter: 66 ; paint: . ; turn: R
# Iter: 67 ; paint: . ; turn: R
# Iter: 68 ; paint: . ; turn: R
# Iter: 69 ; paint: . ; turn: R
# Iter: 70 ; paint: . ; turn: R
# Iter: 71 ; paint: . ; turn: R
# Iter: 72 ; paint: . ; turn: R
# Iter: 73 ; paint: . ; turn: R
# Iter: 74 ; paint: . ; turn: R
# Iter: 75 ; paint: . ; turn: R
# Iter: 76 ; paint: . ; turn: R
# Iter: 77 ; paint: . ; turn: R
# Iter: 78 ; paint: . ; turn: R
# Iter: 79 ; paint: . ; turn: R
# Iter: 80 ; paint: . ; turn: R
# Iter: 81 ; paint: . ; turn: R
# Iter: 82 ; paint: . ; turn: R
# Iter: 83 ; paint: . ; turn: R
# Iter: 84 ; paint: . ; turn: R
# Iter: 85 ; paint: . ; turn: R
# Iter: 86 ; paint: . ; turn: R
# Iter: 87 ; paint: . ; turn: R
# Iter: 88 ; paint: . ; turn: R
# Iter: 89 ; paint: . ; turn: R
# Iter: 90 ; paint: . ; turn: R
# Iter: 91 ; paint: . ; turn: R
# Iter: 92 ; paint: . ; turn: R
# Iter: 93 ; paint: . ; turn: R
# Iter: 94 ; paint: . ; turn: R
# Iter: 95 ; paint: . ; turn: R
# Iter: 96 ; paint: . ; turn: R
# Iter: 97 ; paint: . ; turn: R
# Iter: 98 ; paint: . ; turn: R
# Iter: 99 ; paint: . ; turn: R
# Iter: 100 ; paint: . ; turn: R
# Iter: 101 ; paint: . ; turn: R
# Iter: 102 ; paint: . ; turn: R
# Iter: 103 ; paint: . ; turn: R
# Iter: 104 ; paint: . ; turn: R
# Iter: 105 ; paint: . ; turn: R
# Iter: 106 ; paint: . ; turn: R
# Iter: 107 ; paint: . ; turn: R
# Iter: 108 ; paint: . ; turn: R
# Iter: 109 ; paint: . ; turn: R
# Iter: 110 ; paint: . ; turn: R
# Iter: 111 ; paint: . ; turn: R
# Iter: 112 ; paint: . ; turn: R
# Iter: 113 ; paint: . ; turn: R
# Iter: 114 ; paint: . ; turn: R
# Iter: 115 ; paint: . ; turn: R
# Iter: 116 ; paint: . ; turn: R
# Iter: 117 ; paint: . ; turn: R
# Iter: 118 ; paint: . ; turn: R
# Iter: 119 ; paint: . ; turn: R
# Iter: 120 ; paint: . ; turn: R
# Iter: 121 ; paint: . ; turn: R
# Iter: 122 ; paint: . ; turn: R
# Iter: 123 ; paint: . ; turn: R
# Iter: 124 ; paint: . ; turn: R
# Iter: 125 ; paint: . ; turn: R
# Iter: 126 ; paint: . ; turn: R
# Iter: 127 ; paint: . ; turn: R
# Iter: 128 ; paint: . ; turn: R
# Iter: 129 ; paint: . ; turn: R
# Iter: 130 ; paint: . ; turn: R
# Iter: 131 ; paint: . ; turn: R
# Iter: 132 ; paint: . ; turn: R
# Iter: 133 ; paint: . ; turn: R
# Iter: 134 ; paint: . ; turn: R
# Iter: 135 ; paint: . ; turn: R
# Iter: 136 ; paint: . ; turn: R
# Iter: 137 ; paint: . ; turn: R
# Iter: 138 ; paint: . ; turn: R
# Iter: 139 ; paint: . ; turn: R
# Iter: 140 ; paint: . ; turn: R
# Iter: 141 ; paint: . ; turn: R
# Iter: 142 ; paint: . ; turn: R
# Iter: 143 ; paint: . ; turn: R
# Iter: 144 ; paint: . ; turn: R
# Iter: 145 ; paint: . ; turn: R
# Iter: 146 ; paint: . ; turn: R
# Iter: 147 ; paint: . ; turn: R
# Iter: 148 ; paint: . ; turn: R
# Iter: 149 ; paint: . ; turn: R
# Iter: 150 ; paint: . ; turn: R
# Iter: 151 ; paint: . ; turn: R
# Iter: 152 ; paint: . ; turn: R
# Iter: 153 ; paint: . ; turn: R
# Iter: 154 ; paint: . ; turn: R
# Iter: 155 ; paint: . ; turn: R
# Iter: 156 ; paint: . ; turn: R
# Iter: 157 ; paint: . ; turn: R
# Iter: 158 ; paint: . ; turn: R
# Iter: 159 ; paint: . ; turn: R
# Iter: 160 ; paint: . ; turn: R
# Iter: 161 ; paint: . ; turn: R
# Iter: 162 ; paint: . ; turn: R
# Iter: 163 ; paint: . ; turn: R
# Iter: 164 ; paint: . ; turn: R
# Iter: 165 ; paint: . ; turn: R
# Iter: 166 ; paint: . ; turn: R
# Iter: 167 ; paint: . ; turn: R
# Iter: 168 ; paint: . ; turn: R
# Iter: 169 ; paint: . ; turn: R
# Iter: 170 ; paint: . ; turn: R
# Iter: 171 ; paint: . ; turn: R
# Iter: 172 ; paint: . ; turn: R
# Iter: 173 ; paint: . ; turn: R
# Iter: 174 ; paint: . ; turn: R
# Iter: 175 ; paint: . ; turn: R
# Iter: 176 ; paint: . ; turn: R
# Iter: 177 ; paint: . ; turn: R
# Iter: 178 ; paint: . ; turn: R
# Iter: 179 ; paint: . ; turn: R
# Iter: 180 ; paint: . ; turn: R
# Iter: 181 ; paint: . ; turn: R
# Iter: 182 ; paint: . ; turn: R
# Iter: 183 ; paint: . ; turn: R
# Iter: 184 ; paint: . ; turn: R
# Iter: 185 ; paint: . ; turn: R
# Iter: 186 ; paint: . ; turn: R
# Iter: 187 ; paint: . ; turn: R
# Iter: 188 ; paint: . ; turn: R
# Iter: 189 ; paint: . ; turn: R
# Iter: 190 ; paint: . ; turn: R
# Iter: 191 ; paint: . ; turn: R
# Iter: 192 ; paint: . ; turn: R
# Iter: 193 ; paint: . ; turn: R
# Iter: 194 ; paint: . ; turn: R
# Iter: 195 ; paint: . ; turn: R
# Iter: 196 ; paint: . ; turn: R
# Iter: 197 ; paint: . ; turn: R
# Iter: 198 ; paint: . ; turn: R
# Iter: 199 ; paint: . ; turn: R
# Iter: 200 ; paint: . ; turn: R
# Iter: 201 ; paint: . ; turn: R
# Iter: 202 ; paint: . ; turn: R
# Iter: 203 ; paint: . ; turn: R
# Iter: 204 ; paint: . ; turn: R
# Iter: 205 ; paint: . ; turn: R
# Iter: 206 ; paint: . ; turn: R
# Iter: 207 ; paint: . ; turn: R
# Iter: 208 ; paint: . ; turn: R
# Iter: 209 ; paint: . ; turn: R
# Iter: 210 ; paint: . ; turn: R
# Iter: 211 ; paint: . ; turn: R
# Iter: 212 ; paint: . ; turn: R
# Iter: 213 ; paint: . ; turn: R
# Iter: 214 ; paint: . ; turn: R
# Iter: 215 ; paint: . ; turn: R
# Iter: 216 ; paint: . ; turn: R
# Iter: 217 ; paint: . ; turn: R
# Iter: 218 ; paint: . ; turn: R
# Iter: 219 ; paint: . ; turn: R
# Iter: 220 ; paint: . ; turn: R
# Iter: 221 ; paint: . ; turn: R
# Iter: 222 ; paint: . ; turn: R
# Iter: 223 ; paint: . ; turn: R
# Iter: 224 ; paint: . ; turn: R
# Iter: 225 ; paint: . ; turn: R
# Iter: 226 ; paint: . ; turn: R
# Iter: 227 ; paint: . ; turn: R
# Iter: 228 ; paint: . ; turn: R
# Iter: 229 ; paint: . ; turn: R
# Iter: 230 ; paint: . ; turn: R
# Iter: 231 ; paint: . ; turn: R
# Iter: 232 ; paint: . ; turn: R
# Iter: 233 ; paint: . ; turn: R
# Iter: 234 ; paint: . ; turn: R
# Iter: 235 ; paint: . ; turn: R
# Iter: 236 ; paint: . ; turn: R
# Iter: 237 ; paint: . ; turn: R
# Iter: 238 ; paint: . ; turn: R
# Iter: 239 ; paint: . ; turn: R
# Iter: 240 ; paint: . ; turn: R
# Iter: 241 ; paint: . ; turn: R
# Iter: 242 ; paint: . ; turn: R
# Iter: 243 ; paint: . ; turn: R
# Iter: 244 ; paint: . ; turn: R
# Iter: 245 ; paint: . ; turn: R
# Iter: 246 ; paint: . ; turn: R
# Iter: 247 ; paint: . ; turn: R
# Iter: 248 ; paint: . ; turn: R
# Iter: 249 ; paint: . ; turn: R
# Iter: 250 ; paint: . ; turn: R
# Iter: 251 ; paint: . ; turn: R
# Iter: 252 ; paint: . ; turn: R
# Iter: 253 ; paint: . ; turn: R
# Iter: 254 ; paint: . ; turn: R
# Iter: 255 ; paint: . ; turn: R
# Iter: 256 ; paint: . ; turn: R
# Iter: 257 ; paint: . ; turn: R
# Iter: 258 ; paint: . ; turn: R
# Iter: 259 ; paint: . ; turn: R
# Iter: 260 ; paint: . ; turn: R
# Iter: 261 ; paint: . ; turn: R
# Iter: 262 ; paint: . ; turn: R
# Iter: 263 ; paint: . ; turn: R
# Iter: 264 ; paint: . ; turn: R
# Iter: 265 ; paint: . ; turn: R
# Iter: 266 ; paint: . ; turn: R
# Iter: 267 ; paint: . ; turn: R
# Iter: 268 ; paint: . ; turn: R
# Iter: 269 ; paint: . ; turn: R
# Iter: 270 ; paint: . ; turn: R
# Iter: 271 ; paint: . ; turn: R
# Iter: 272 ; paint: . ; turn: R
# Iter: 273 ; paint: . ; turn: R
# Iter: 274 ; paint: . ; turn: R
# Iter: 275 ; paint: . ; turn: R
# Iter: 276 ; paint: . ; turn: R
# Iter: 277 ; paint: . ; turn: R
# Iter: 278 ; paint: . ; turn: R
# Iter: 279 ; paint: . ; turn: R
# Iter: 280 ; paint: . ; turn: R
# Iter: 281 ; paint: . ; turn: R
# Iter: 282 ; paint: . ; turn: R
# Iter: 283 ; paint: . ; turn: R
# Iter: 284 ; paint: . ; turn: R
# Iter: 285 ; paint: . ; turn: R
# Iter: 286 ; paint: . ; turn: R
# Iter: 287 ; paint: . ; turn: R
# Iter: 288 ; paint: . ; turn: R
# Iter: 289 ; paint: . ; turn: R
# Iter: 290 ; paint: . ; turn: R
# Iter: 291 ; paint: . ; turn: R
# Iter: 292 ; paint: . ; turn: R
# Iter: 293 ; paint: . ; turn: R
# Iter: 294 ; paint: . ; turn: R
# Iter: 295 ; paint: . ; turn: R
# Iter: 296 ; paint: . ; turn: R
# Iter: 297 ; paint: . ; turn: R
# Iter: 298 ; paint: . ; turn: R
# Iter: 299 ; paint: . ; turn: R
# Iter: 300 ; paint: . ; turn: R
# Iter: 301 ; paint: . ; turn: R
# Iter: 302 ; paint: . ; turn: R
# Iter: 303 ; paint: . ; turn: R
# Iter: 304 ; paint: . ; turn: R
# Iter: 305 ; paint: . ; turn: R
# Iter: 306 ; paint: . ; turn: R
# Iter: 307 ; paint: . ; turn: R
# Iter: 308 ; paint: . ; turn: R
# Iter: 309 ; paint: . ; turn: R
# Iter: 310 ; paint: . ; turn: R
# Iter: 311 ; paint: . ; turn: R
# Iter: 312 ; paint: . ; turn: R
# Iter: 313 ; paint: . ; turn: R
# Iter: 314 ; paint: . ; turn: R
# Iter: 315 ; paint: . ; turn: R
# Iter: 316 ; paint: . ; turn: R
# Iter: 317 ; paint: . ; turn: R
# Iter: 318 ; paint: . ; turn: R
# Iter: 319 ; paint: . ; turn: R
# Iter: 320 ; paint: . ; turn: R
# Iter: 321 ; paint: . ; turn: R
# Iter: 322 ; paint: . ; turn: R
# Iter: 323 ; paint: . ; turn: R
# Iter: 324 ; paint: . ; turn: R
# Iter: 325 ; paint: . ; turn: R
# Iter: 326 ; paint: . ; turn: R
# Iter: 327 ; paint: . ; turn: R
# Iter: 328 ; paint: . ; turn: R
# Iter: 329 ; paint: . ; turn: R
# Iter: 330 ; paint: . ; turn: R
# Iter: 331 ; paint: . ; turn: R
# Iter: 332 ; paint: . ; turn: R
# Iter: 333 ; paint: . ; turn: R
# Iter: 334 ; paint: . ; turn: R
# Iter: 335 ; paint: . ; turn: R
# Iter: 336 ; paint: . ; turn: R
# Iter: 337 ; paint: . ; turn: R
# Iter: 338 ; paint: . ; turn: R
# Iter: 339 ; paint: . ; turn: R
# Iter: 340 ; paint: . ; turn: R
# Iter: 341 ; paint: . ; turn: R
# Iter: 342 ; paint: . ; turn: R
# Iter: 343 ; paint: . ; turn: R
# Iter: 344 ; paint: . ; turn: R
# Iter: 345 ; paint: . ; turn: R
# Iter: 346 ; paint: . ; turn: R
# Iter: 347 ; paint: . ; turn: R
# Iter: 348 ; paint: . ; turn: R
# Iter: 349 ; paint: . ; turn: R
# Iter: 350 ; paint: . ; turn: R
# Iter: 351 ; paint: . ; turn: R
# Iter: 352 ; paint: . ; turn: R
# Iter: 353 ; paint: . ; turn: R
# Iter: 354 ; paint: . ; turn: R
# Iter: 355 ; paint: . ; turn: R
# Iter: 356 ; paint: . ; turn: R
# Iter: 357 ; paint: . ; turn: R
# Iter: 358 ; paint: . ; turn: R
# Iter: 359 ; paint: . ; turn: R
# Iter: 360 ; paint: . ; turn: R
# Iter: 361 ; paint: . ; turn: R
# Iter: 362 ; paint: . ; turn: R
# Iter: 363 ; paint: . ; turn: R
# Iter: 364 ; paint: . ; turn: R
# Iter: 365 ; paint: . ; turn: R
# Iter: 366 ; paint: . ; turn: R
# Iter: 367 ; paint: . ; turn: R
# Iter: 368 ; paint: . ; turn: R
# Iter: 369 ; paint: . ; turn: R
# Iter: 370 ; paint: . ; turn: R
# Iter: 371 ; paint: . ; turn: R
# Iter: 372 ; paint: . ; turn: R
# Iter: 373 ; paint: . ; turn: R
# Iter: 374 ; paint: . ; turn: R
# Iter: 375 ; paint: . ; turn: R
# Iter: 376 ; paint: . ; turn: R
# Iter: 377 ; paint: . ; turn: R
# Iter: 378 ; paint: . ; turn: R
# Iter: 379 ; paint: . ; turn: R
# Iter: 380 ; paint: . ; turn: R
# Iter: 381 ; paint: . ; turn: R
# Iter: 382 ; paint: . ; turn: R
# Iter: 383 ; paint: . ; turn: R
# Iter: 384 ; paint: . ; turn: R
# Iter: 385 ; paint: . ; turn: R
# Iter: 386 ; paint: . ; turn: R
# Iter: 387 ; paint: . ; turn: R
# Iter: 388 ; paint: . ; turn: R
# Iter: 389 ; paint: . ; turn: R
# Iter: 390 ; paint: . ; turn: R
# Iter: 391 ; paint: . ; turn: R
# Iter: 392 ; paint: . ; turn: R
# Iter: 393 ; paint: . ; turn: R
# Iter: 394 ; paint: . ; turn: R
# Iter: 395 ; paint: . ; turn: R
# Iter: 396 ; paint: . ; turn: R
# Iter: 397 ; paint: . ; turn: R
# Iter: 398 ; paint: . ; turn: R
# Iter: 399 ; paint: . ; turn: R
# Iter: 400 ; paint: . ; turn: R
# Iter: 401 ; paint: . ; turn: R
# Iter: 402 ; paint: . ; turn: R
# Iter: 403 ; paint: . ; turn: R
# Iter: 404 ; paint: . ; turn: R
# Iter: 405 ; paint: . ; turn: R
# Iter: 406 ; paint: . ; turn: R
# Iter: 407 ; paint: . ; turn: R
# Iter: 408 ; paint: . ; turn: R
# Iter: 409 ; paint: . ; turn: R
# Iter: 410 ; paint: . ; turn: R
# Iter: 411 ; paint: . ; turn: R
# Iter: 412 ; paint: . ; turn: R
# Iter: 413 ; paint: . ; turn: R
# Iter: 414 ; paint: . ; turn: R
# Iter: 415 ; paint: . ; turn: R
# Iter: 416 ; paint: . ; turn: R
# Iter: 417 ; paint: . ; turn: R
# Iter: 418 ; paint: . ; turn: R
# Iter: 419 ; paint: . ; turn: R
# Iter: 420 ; paint: . ; turn: R
# Iter: 421 ; paint: . ; turn: R
# Iter: 422 ; paint: . ; turn: R
# Iter: 423 ; paint: . ; turn: R
# Iter: 424 ; paint: . ; turn: R
# Iter: 425 ; paint: . ; turn: R
# Iter: 426 ; paint: . ; turn: R
# Iter: 427 ; paint: . ; turn: R
# Iter: 428 ; paint: . ; turn: R
# Iter: 429 ; paint: . ; turn: R
# Iter: 430 ; paint: . ; turn: R
# Iter: 431 ; paint: . ; turn: R
# Iter: 432 ; paint: . ; turn: R
# Iter: 433 ; paint: . ; turn: R
# Iter: 434 ; paint: . ; turn: R
# Iter: 435 ; paint: . ; turn: R
# Iter: 436 ; paint: . ; turn: R
# Iter: 437 ; paint: . ; turn: R
# Iter: 438 ; paint: . ; turn: R
# Iter: 439 ; paint: . ; turn: R
# Iter: 440 ; paint: . ; turn: R
# Iter: 441 ; paint: . ; turn: R
# Iter: 442 ; paint: . ; turn: R
# Iter: 443 ; paint: . ; turn: R
# Iter: 444 ; paint: . ; turn: R
# Iter: 445 ; paint: . ; turn: R
# Iter: 446 ; paint: . ; turn: R
# Iter: 447 ; paint: . ; turn: R
# Iter: 448 ; paint: . ; turn: R
# Iter: 449 ; paint: . ; turn: R
# Iter: 450 ; paint: . ; turn: R
# Iter: 451 ; paint: . ; turn: R
# Iter: 452 ; paint: . ; turn: R
# Iter: 453 ; paint: . ; turn: R
# Iter: 454 ; paint: . ; turn: R
# Iter: 455 ; paint: . ; turn: R
# Iter: 456 ; paint: . ; turn: R
# Iter: 457 ; paint: . ; turn: R
# Iter: 458 ; paint: . ; turn: R
# Iter: 459 ; paint: . ; turn: R
# Iter: 460 ; paint: . ; turn: R
# Iter: 461 ; paint: . ; turn: R
# Iter: 462 ; paint: . ; turn: R
# Iter: 463 ; paint: . ; turn: R
# Iter: 464 ; paint: . ; turn: R
# Iter: 465 ; paint: . ; turn: R
# Iter: 466 ; paint: . ; turn: R
# Iter: 467 ; paint: . ; turn: R
# Iter: 468 ; paint: . ; turn: R
# Iter: 469 ; paint: . ; turn: R
# Iter: 470 ; paint: . ; turn: R
# Iter: 471 ; paint: . ; turn: R
# Iter: 472 ; paint: . ; turn: R
# Iter: 473 ; paint: . ; turn: R
# Iter: 474 ; paint: . ; turn: R
# Iter: 475 ; paint: . ; turn: R
# Iter: 476 ; paint: . ; turn: R
# Iter: 477 ; paint: . ; turn: R
# Iter: 478 ; paint: . ; turn: R
# Iter: 479 ; paint: . ; turn: R
# Iter: 480 ; paint: . ; turn: R
# Iter: 481 ; paint: . ; turn: R
# Iter: 482 ; paint: . ; turn: R
# Iter: 483 ; paint: . ; turn: R
# Iter: 484 ; paint: . ; turn: R
# Iter: 485 ; paint: . ; turn: R
# Iter: 486 ; paint: . ; turn: R
# Iter: 487 ; paint: . ; turn: R
# Iter: 488 ; paint: . ; turn: R
# Iter: 489 ; paint: . ; turn: R
# Iter: 490 ; paint: . ; turn: R
# Iter: 491 ; paint: . ; turn: R
# Iter: 492 ; paint: . ; turn: R
# Iter: 493 ; paint: . ; turn: R
# Iter: 494 ; paint: . ; turn: R
# Iter: 495 ; paint: . ; turn: R
# Iter: 496 ; paint: . ; turn: R
# Iter: 497 ; paint: . ; turn: R
# Iter: 498 ; paint: . ; turn: R
# Iter: 499 ; paint: . ; turn: R
# Iter: 500 ; paint: . ; turn: R
# Iter: 501 ; paint: . ; turn: R
# Iter: 502 ; paint: . ; turn: R
# Iter: 503 ; paint: . ; turn: R
# Iter: 504 ; paint: . ; turn: R
# Iter: 505 ; paint: . ; turn: R
# Iter: 506 ; paint: . ; turn: R
# Iter: 507 ; paint: . ; turn: R
# Iter: 508 ; paint: . ; turn: R
# Iter: 509 ; paint: . ; turn: R
# Iter: 510 ; paint: . ; turn: R
# Iter: 511 ; paint: . ; turn: R
# Iter: 512 ; paint: . ; turn: R
# Iter: 513 ; paint: . ; turn: R
# Iter: 514 ; paint: . ; turn: R
# Iter: 515 ; paint: . ; turn: R
# Iter: 516 ; paint: . ; turn: R
# Iter: 517 ; paint: . ; turn: R
# Iter: 518 ; paint: . ; turn: R
# Iter: 519 ; paint: . ; turn: R
# Iter: 520 ; paint: . ; turn: R
# Iter: 521 ; paint: . ; turn: R
# Iter: 522 ; paint: . ; turn: R
# Iter: 523 ; paint: . ; turn: R
# Iter: 524 ; paint: . ; turn: R
# Iter: 525 ; paint: . ; turn: R
# Iter: 526 ; paint: . ; turn: R
# Iter: 527 ; paint: . ; turn: R
# Iter: 528 ; paint: . ; turn: R
# Iter: 529 ; paint: . ; turn: R
# Iter: 530 ; paint: . ; turn: R
# Iter: 531 ; paint: . ; turn: R
# Iter: 532 ; paint: . ; turn: R
# Iter: 533 ; paint: . ; turn: R
# Iter: 534 ; paint: . ; turn: R
# Iter: 535 ; paint: . ; turn: R
# Iter: 536 ; paint: . ; turn: R
# Iter: 537 ; paint: . ; turn: R
# Iter: 538 ; paint: . ; turn: R
# Iter: 539 ; paint: . ; turn: R
# Iter: 540 ; paint: . ; turn: R
# Iter: 541 ; paint: . ; turn: R
# Iter: 542 ; paint: . ; turn: R
# Iter: 543 ; paint: . ; turn: R
# Iter: 544 ; paint: . ; turn: R
# Iter: 545 ; paint: . ; turn: R
# Iter: 546 ; paint: . ; turn: R
# Iter: 547 ; paint: . ; turn: R
# Iter: 548 ; paint: . ; turn: R
# Iter: 549 ; paint: . ; turn: R
# Iter: 550 ; paint: . ; turn: R
# Iter: 551 ; paint: . ; turn: R
# Iter: 552 ; paint: . ; turn: R
# Iter: 553 ; paint: . ; turn: R
# Iter: 554 ; paint: . ; turn: R
# Iter: 555 ; paint: . ; turn: R
# Iter: 556 ; paint: . ; turn: R
# Iter: 557 ; paint: . ; turn: R
# Iter: 558 ; paint: . ; turn: R
# Iter: 559 ; paint: . ; turn: R
# Iter: 560 ; paint: . ; turn: R
# Iter: 561 ; paint: . ; turn: R
# Iter: 562 ; paint: . ; turn: R
# Iter: 563 ; paint: . ; turn: R
# Iter: 564 ; paint: . ; turn: R
# Iter: 565 ; paint: . ; turn: R
# Iter: 566 ; paint: . ; turn: R
# Iter: 567 ; paint: . ; turn: R
# Iter: 568 ; paint: . ; turn: R
# Iter: 569 ; paint: . ; turn: R
# Iter: 570 ; paint: . ; turn: R
# Iter: 571 ; paint: . ; turn: R
# Iter: 572 ; paint: . ; turn: R
# Iter: 573 ; paint: . ; turn: R
# Iter: 574 ; paint: . ; turn: R
# Iter: 575 ; paint: . ; turn: R
# Iter: 576 ; paint: . ; turn: R
# Iter: 577 ; paint: . ; turn: R
# Iter: 578 ; paint: . ; turn: R
# Iter: 579 ; paint: . ; turn: R
# Iter: 580 ; paint: . ; turn: R
# Iter: 581 ; paint: . ; turn: R
# Iter: 582 ; paint: . ; turn: R
# Iter: 583 ; paint: . ; turn: R
# Iter: 584 ; paint: . ; turn: R
# Iter: 585 ; paint: . ; turn: R
# Iter: 586 ; paint: . ; turn: R
# Iter: 587 ; paint: . ; turn: R
# Iter: 588 ; paint: . ; turn: R
# Iter: 589 ; paint: . ; turn: R
# Iter: 590 ; paint: . ; turn: R
# Iter: 591 ; paint: . ; turn: R
# Iter: 592 ; paint: . ; turn: R
# Iter: 593 ; paint: . ; turn: R
# Iter: 594 ; paint: . ; turn: R
# Iter: 595 ; paint: . ; turn: R
# Iter: 596 ; paint: . ; turn: R
# Iter: 597 ; paint: . ; turn: R
# Iter: 598 ; paint: . ; turn: R
# Iter: 599 ; paint: . ; turn: R
# Iter: 600 ; paint: . ; turn: R
# Iter: 601 ; paint: . ; turn: R
# Iter: 602 ; paint: . ; turn: R
# Iter: 603 ; paint: . ; turn: R
# Iter: 604 ; paint: . ; turn: R
# Iter: 605 ; paint: . ; turn: R
# Iter: 606 ; paint: . ; turn: R
# Iter: 607 ; paint: . ; turn: R
# Iter: 608 ; paint: . ; turn: R
# Iter: 609 ; paint: . ; turn: R
# Iter: 610 ; paint: . ; turn: R
# Iter: 611 ; paint: . ; turn: R
# Iter: 612 ; paint: . ; turn: R
# Iter: 613 ; paint: . ; turn: R
# Iter: 614 ; paint: . ; turn: R
# Iter: 615 ; paint: . ; turn: R
# Iter: 616 ; paint: . ; turn: R
# Iter: 617 ; paint: . ; turn: R
# Iter: 618 ; paint: . ; turn: R
# Iter: 619 ; paint: . ; turn: R
# Iter: 620 ; paint: . ; turn: R
# Iter: 621 ; paint: . ; turn: R
# Iter: 622 ; paint: . ; turn: R
# Iter: 623 ; paint: . ; turn: R
# Iter: 624 ; paint: . ; turn: R
# Iter: 625 ; paint: . ; turn: R
# Iter: 626 ; paint: . ; turn: R
# Iter: 627 ; paint: . ; turn: R
# Iter: 628 ; paint: . ; turn: R
# Iter: 629 ; paint: . ; turn: R
# Iter: 630 ; paint: . ; turn: R
# Iter: 631 ; paint: . ; turn: R
# Iter: 632 ; paint: . ; turn: R
# Iter: 633 ; paint: . ; turn: R
# Iter: 634 ; paint: . ; turn: R
# Iter: 635 ; paint: . ; turn: R
# Iter: 636 ; paint: . ; turn: R
# Iter: 637 ; paint: . ; turn: R
# Iter: 638 ; paint: . ; turn: R
# Iter: 639 ; paint: . ; turn: R
# Iter: 640 ; paint: . ; turn: R
# Iter: 641 ; paint: . ; turn: R
# Iter: 642 ; paint: . ; turn: R
# Iter: 643 ; paint: . ; turn: R
# Iter: 644 ; paint: . ; turn: R
# Iter: 645 ; paint: . ; turn: R
# Iter: 646 ; paint: . ; turn: R
# Iter: 647 ; paint: . ; turn: R
# Iter: 648 ; paint: . ; turn: R
# Iter: 649 ; paint: . ; turn: R
# Iter: 650 ; paint: . ; turn: R
# Iter: 651 ; paint: . ; turn: R
# Iter: 652 ; paint: . ; turn: R
# Iter: 653 ; paint: . ; turn: R
# Iter: 654 ; paint: . ; turn: R
# Iter: 655 ; paint: . ; turn: R
# Iter: 656 ; paint: . ; turn: R
# Iter: 657 ; paint: . ; turn: R
# Iter: 658 ; paint: . ; turn: R
# Iter: 659 ; paint: . ; turn: R
# Iter: 660 ; paint: . ; turn: R
# Iter: 661 ; paint: . ; turn: R
# Iter: 662 ; paint: . ; turn: R
# Iter: 663 ; paint: . ; turn: R
# Iter: 664 ; paint: . ; turn: R
# Iter: 665 ; paint: . ; turn: R
# Iter: 666 ; paint: . ; turn: R
# Iter: 667 ; paint: . ; turn: R
# Iter: 668 ; paint: . ; turn: R
# Iter: 669 ; paint: . ; turn: R
# Iter: 670 ; paint: . ; turn: R
# Iter: 671 ; paint: . ; turn: R
# Iter: 672 ; paint: . ; turn: R
# Iter: 673 ; paint: . ; turn: R
# Iter: 674 ; paint: . ; turn: R
# Iter: 675 ; paint: . ; turn: R
# Iter: 676 ; paint: . ; turn: R
# Iter: 677 ; paint: . ; turn: R
# Iter: 678 ; paint: . ; turn: R
# Iter: 679 ; paint: . ; turn: R
# Iter: 680 ; paint: . ; turn: R
# Iter: 681 ; paint: . ; turn: R
# Iter: 682 ; paint: . ; turn: R
# Iter: 683 ; paint: . ; turn: R
# Iter: 684 ; paint: . ; turn: R
# Iter: 685 ; paint: . ; turn: R
# Iter: 686 ; paint: . ; turn: R
# Iter: 687 ; paint: . ; turn: R
# Iter: 688 ; paint: . ; turn: R
# Iter: 689 ; paint: . ; turn: R
# Iter: 690 ; paint: . ; turn: R
# Iter: 691 ; paint: . ; turn: R
# Iter: 692 ; paint: . ; turn: R
# Iter: 693 ; paint: . ; turn: R
# Iter: 694 ; paint: . ; turn: R
# Iter: 695 ; paint: . ; turn: R
# Iter: 696 ; paint: . ; turn: R
# Iter: 697 ; paint: . ; turn: R
# Iter: 698 ; paint: . ; turn: R
# Iter: 699 ; paint: . ; turn: R
# Iter: 700 ; paint: . ; turn: R
# Iter: 701 ; paint: . ; turn: R
# Iter: 702 ; paint: . ; turn: R
# Iter: 703 ; paint: . ; turn: R
# Iter: 704 ; paint: . ; turn: R
# Iter: 705 ; paint: . ; turn: R
# Iter: 706 ; paint: . ; turn: R
# Iter: 707 ; paint: . ; turn: R
# Iter: 708 ; paint: . ; turn: R
# Iter: 709 ; paint: . ; turn: R
# Iter: 710 ; paint: . ; turn: R
# Iter: 711 ; paint: . ; turn: R
# Iter: 712 ; paint: . ; turn: R
# Iter: 713 ; paint: . ; turn: R
# Iter: 714 ; paint: . ; turn: R
# Iter: 715 ; paint: . ; turn: R
# Iter: 716 ; paint: . ; turn: R
# Iter: 717 ; paint: . ; turn: R
# Iter: 718 ; paint: . ; turn: R
# Iter: 719 ; paint: . ; turn: R
# Iter: 720 ; paint: . ; turn: R
# Iter: 721 ; paint: . ; turn: R
# Iter: 722 ; paint: . ; turn: R
# Iter: 723 ; paint: . ; turn: R
# Iter: 724 ; paint: . ; turn: R
# Iter: 725 ; paint: . ; turn: R
# Iter: 726 ; paint: . ; turn: R
# Iter: 727 ; paint: . ; turn: R
# Iter: 728 ; paint: . ; turn: R
# Iter: 729 ; paint: . ; turn: R
# Iter: 730 ; paint: . ; turn: R
# Iter: 731 ; paint: . ; turn: R
# Iter: 732 ; paint: . ; turn: R
# Iter: 733 ; paint: . ; turn: R
# Iter: 734 ; paint: . ; turn: R
# Iter: 735 ; paint: . ; turn: R
# Iter: 736 ; paint: . ; turn: R
# Iter: 737 ; paint: . ; turn: R
# Iter: 738 ; paint: . ; turn: R
# Iter: 739 ; paint: . ; turn: R
# Iter: 740 ; paint: . ; turn: R
# Iter: 741 ; paint: . ; turn: R
# Iter: 742 ; paint: . ; turn: R
# Iter: 743 ; paint: . ; turn: R
# Iter: 744 ; paint: . ; turn: R
# Iter: 745 ; paint: . ; turn: R
# Iter: 746 ; paint: . ; turn: R
# Iter: 747 ; paint: . ; turn: R
# Iter: 748 ; paint: . ; turn: R
# Iter: 749 ; paint: . ; turn: R
# Iter: 750 ; paint: . ; turn: R
# Iter: 751 ; paint: . ; turn: R
# Iter: 752 ; paint: . ; turn: R
# Iter: 753 ; paint: . ; turn: R
# Iter: 754 ; paint: . ; turn: R
# Iter: 755 ; paint: . ; turn: R
# Iter: 756 ; paint: . ; turn: R
# Iter: 757 ; paint: . ; turn: R
# Iter: 758 ; paint: . ; turn: R
# Iter: 759 ; paint: . ; turn: R
# Iter: 760 ; paint: . ; turn: R
# Iter: 761 ; paint: . ; turn: R
# Iter: 762 ; paint: . ; turn: R
# Iter: 763 ; paint: . ; turn: R
# Iter: 764 ; paint: . ; turn: R
# Iter: 765 ; paint: . ; turn: R
# Iter: 766 ; paint: . ; turn: R
# Iter: 767 ; paint: . ; turn: R
# Iter: 768 ; paint: . ; turn: R
# Iter: 769 ; paint: . ; turn: R
# Iter: 770 ; paint: . ; turn: R
# Iter: 771 ; paint: . ; turn: R
# Iter: 772 ; paint: . ; turn: R
# Iter: 773 ; paint: . ; turn: R
# Iter: 774 ; paint: . ; turn: R
# Iter: 775 ; paint: . ; turn: R
# Iter: 776 ; paint: . ; turn: R
# Iter: 777 ; paint: . ; turn: R
# Iter: 778 ; paint: . ; turn: R
# Iter: 779 ; paint: . ; turn: R
# Iter: 780 ; paint: . ; turn: R
# Iter: 781 ; paint: . ; turn: R
# Iter: 782 ; paint: . ; turn: R
# Iter: 783 ; paint: . ; turn: R
# Iter: 784 ; paint: . ; turn: R
# Iter: 785 ; paint: . ; turn: R
# Iter: 786 ; paint: . ; turn: R
# Iter: 787 ; paint: . ; turn: R
# Iter: 788 ; paint: . ; turn: R
# Iter: 789 ; paint: . ; turn: R
# Iter: 790 ; paint: . ; turn: R
# Iter: 791 ; paint: . ; turn: R
# Iter: 792 ; paint: . ; turn: R
# Iter: 793 ; paint: . ; turn: R
# Iter: 794 ; paint: . ; turn: R
# Iter: 795 ; paint: . ; turn: R
# Iter: 796 ; paint: . ; turn: R
# Iter: 797 ; paint: . ; turn: R
# Iter: 798 ; paint: . ; turn: R
# Iter: 799 ; paint: . ; turn: R
# Iter: 800 ; paint: . ; turn: R
# Iter: 801 ; paint: . ; turn: R
# Iter: 802 ; paint: . ; turn: R
# Iter: 803 ; paint: . ; turn: R
# Iter: 804 ; paint: . ; turn: R
# Iter: 805 ; paint: . ; turn: R
# Iter: 806 ; paint: . ; turn: R
# Iter: 807 ; paint: . ; turn: R
# Iter: 808 ; paint: . ; turn: R
# Iter: 809 ; paint: . ; turn: R
# Iter: 810 ; paint: . ; turn: R
# Iter: 811 ; paint: . ; turn: R
# Iter: 812 ; paint: . ; turn: R
# Iter: 813 ; paint: . ; turn: R
# Iter: 814 ; paint: . ; turn: R
# Iter: 815 ; paint: . ; turn: R
# Iter: 816 ; paint: . ; turn: R
# Iter: 817 ; paint: . ; turn: R
# Iter: 818 ; paint: . ; turn: R
# Iter: 819 ; paint: . ; turn: R
# Iter: 820 ; paint: . ; turn: R
# Iter: 821 ; paint: . ; turn: R
# Iter: 822 ; paint: . ; turn: R
# Iter: 823 ; paint: . ; turn: R
# Iter: 824 ; paint: . ; turn: R
# Iter: 825 ; paint: . ; turn: R
# Iter: 826 ; paint: . ; turn: R
# Iter: 827 ; paint: . ; turn: R
# Iter: 828 ; paint: . ; turn: R
# Iter: 829 ; paint: . ; turn: R
# Iter: 830 ; paint: . ; turn: R
# Iter: 831 ; paint: . ; turn: R
# Iter: 832 ; paint: . ; turn: R
# Iter: 833 ; paint: . ; turn: R
# Iter: 834 ; paint: . ; turn: R
# Iter: 835 ; paint: . ; turn: R
# Iter: 836 ; paint: . ; turn: R
# Iter: 837 ; paint: . ; turn: R
# Iter: 838 ; paint: . ; turn: R
# Iter: 839 ; paint: . ; turn: R
# Iter: 840 ; paint: . ; turn: R
# Iter: 841 ; paint: . ; turn: R
# Iter: 842 ; paint: . ; turn: R
# Iter: 843 ; paint: . ; turn: R
# Iter: 844 ; paint: . ; turn: R
# Iter: 845 ; paint: . ; turn: R
# Iter: 846 ; paint: . ; turn: R
# Iter: 847 ; paint: . ; turn: R
# Iter: 848 ; paint: . ; turn: R
# Iter: 849 ; paint: . ; turn: R
# Iter: 850 ; paint: . ; turn: R
# Iter: 851 ; paint: . ; turn: R
# Iter: 852 ; paint: . ; turn: R
# Iter: 853 ; paint: . ; turn: R
# Iter: 854 ; paint: . ; turn: R
# Iter: 855 ; paint: . ; turn: R
# Iter: 856 ; paint: . ; turn: R
# Iter: 857 ; paint: . ; turn: R
# Iter: 858 ; paint: . ; turn: R
# Iter: 859 ; paint: . ; turn: R
# Iter: 860 ; paint: . ; turn: R
# Iter: 861 ; paint: . ; turn: R
# Iter: 862 ; paint: . ; turn: R
# Iter: 863 ; paint: . ; turn: R
# Iter: 864 ; paint: . ; turn: R
# Iter: 865 ; paint: . ; turn: R
# Iter: 866 ; paint: . ; turn: R
# Iter: 867 ; paint: . ; turn: R
# Iter: 868 ; paint: . ; turn: R
# Iter: 869 ; paint: . ; turn: R
# Iter: 870 ; paint: . ; turn: R
# Iter: 871 ; paint: . ; turn: R
# Iter: 872 ; paint: . ; turn: R
# Iter: 873 ; paint: . ; turn: R
# Iter: 874 ; paint: . ; turn: R
# Iter: 875 ; paint: . ; turn: R
# Iter: 876 ; paint: . ; turn: R
# Iter: 877 ; paint: . ; turn: R
# Iter: 878 ; paint: . ; turn: R
# Iter: 879 ; paint: . ; turn: R
# Iter: 880 ; paint: . ; turn: R
# Iter: 881 ; paint: . ; turn: R
# Iter: 882 ; paint: . ; turn: R
# Iter: 883 ; paint: . ; turn: R
# Iter: 884 ; paint: . ; turn: R
# Iter: 885 ; paint: . ; turn: R
# Iter: 886 ; paint: . ; turn: R
# Iter: 887 ; paint: . ; turn: R
# Iter: 888 ; paint: . ; turn: R
# Iter: 889 ; paint: . ; turn: R
# Iter: 890 ; paint: . ; turn: R
# Iter: 891 ; paint: . ; turn: R
# Iter: 892 ; paint: . ; turn: R
# Iter: 893 ; paint: . ; turn: R
# Iter: 894 ; paint: . ; turn: R
# Iter: 895 ; paint: . ; turn: R
# Iter: 896 ; paint: . ; turn: R
# Iter: 897 ; paint: . ; turn: R
# Iter: 898 ; paint: . ; turn: R
# Iter: 899 ; paint: . ; turn: R
# Iter: 900 ; paint: . ; turn: R
# Iter: 901 ; paint: . ; turn: R
# Iter: 902 ; paint: . ; turn: R
# Iter: 903 ; paint: . ; turn: R
# Iter: 904 ; paint: . ; turn: R
# Iter: 905 ; paint: . ; turn: R
# Iter: 906 ; paint: . ; turn: R
# Iter: 907 ; paint: . ; turn: R
# Iter: 908 ; paint: . ; turn: R
# Iter: 909 ; paint: . ; turn: R
# Iter: 910 ; paint: . ; turn: R
# Iter: 911 ; paint: . ; turn: R
# Iter: 912 ; paint: . ; turn: R
# Iter: 913 ; paint: . ; turn: R
# Iter: 914 ; paint: . ; turn: R
# Iter: 915 ; paint: . ; turn: R
# Iter: 916 ; paint: . ; turn: R
# Iter: 917 ; paint: . ; turn: R
# Iter: 918 ; paint: . ; turn: R
# Iter: 919 ; paint: . ; turn: R
# Iter: 920 ; paint: . ; turn: R
# Iter: 921 ; paint: . ; turn: R
# Iter: 922 ; paint: . ; turn: R
# Iter: 923 ; paint: . ; turn: R
# Iter: 924 ; paint: . ; turn: R
# Iter: 925 ; paint: . ; turn: R
# Iter: 926 ; paint: . ; turn: R
# Iter: 927 ; paint: . ; turn: R
# Iter: 928 ; paint: . ; turn: R
# Iter: 929 ; paint: . ; turn: R
# Iter: 930 ; paint: . ; turn: R
# Iter: 931 ; paint: . ; turn: R
# Iter: 932 ; paint: . ; turn: R
# Iter: 933 ; paint: . ; turn: R
# Iter: 934 ; paint: . ; turn: R
# Iter: 935 ; paint: . ; turn: R
# Iter: 936 ; paint: . ; turn: R
# Iter: 937 ; paint: . ; turn: R
# Iter: 938 ; paint: . ; turn: R
# Iter: 939 ; paint: . ; turn: R
# Iter: 940 ; paint: . ; turn: R
# Iter: 941 ; paint: . ; turn: R
# Iter: 942 ; paint: . ; turn: R
# Iter: 943 ; paint: . ; turn: R
# Iter: 944 ; paint: . ; turn: R
# Iter: 945 ; paint: . ; turn: R
# Iter: 946 ; paint: . ; turn: R
# Iter: 947 ; paint: . ; turn: R
# Iter: 948 ; paint: . ; turn: R
# Iter: 949 ; paint: . ; turn: R
# Iter: 950 ; paint: . ; turn: R
# Iter: 951 ; paint: . ; turn: R
# Iter: 952 ; paint: . ; turn: R
# Iter: 953 ; paint: . ; turn: R
# Iter: 954 ; paint: . ; turn: R
# Iter: 955 ; paint: . ; turn: R
# Iter: 956 ; paint: . ; turn: R
# Iter: 957 ; paint: . ; turn: R
# Iter: 958 ; paint: . ; turn: R
# Iter: 959 ; paint: . ; turn: R
# Iter: 960 ; paint: . ; turn: R
# Iter: 961 ; paint: . ; turn: R
# Iter: 962 ; paint: . ; turn: R
# Iter: 963 ; paint: . ; turn: R
# Iter: 964 ; paint: . ; turn: R
# Iter: 965 ; paint: . ; turn: R
# Iter: 966 ; paint: . ; turn: R
# Iter: 967 ; paint: . ; turn: R
# Iter: 968 ; paint: . ; turn: R
# Iter: 969 ; paint: . ; turn: R
# Iter: 970 ; paint: . ; turn: R
# Iter: 971 ; paint: . ; turn: R
# Iter: 972 ; paint: . ; turn: R
# Iter: 973 ; paint: . ; turn: R
# Iter: 974 ; paint: . ; turn: R
# Iter: 975 ; paint: . ; turn: R
# Iter: 976 ; paint: . ; turn: R
# Iter: 977 ; paint: . ; turn: R
# Iter: 978 ; paint: . ; turn: R
# Iter: 979 ; paint: . ; turn: R
# Iter: 980 ; paint: . ; turn: R
# Iter: 981 ; paint: . ; turn: R
# Iter: 982 ; paint: . ; turn: R
# Iter: 983 ; paint: . ; turn: R
# Iter: 984 ; paint: . ; turn: R
# Iter: 985 ; paint: . ; turn: R
# Iter: 986 ; paint: . ; turn: R
# Iter: 987 ; paint: . ; turn: R
# Iter: 988 ; paint: . ; turn: R
# Iter: 989 ; paint: . ; turn: R
# Iter: 990 ; paint: . ; turn: R
# Iter: 991 ; paint: . ; turn: R
# Iter: 992 ; paint: . ; turn: R
# Iter: 993 ; paint: . ; turn: R
# Iter: 994 ; paint: . ; turn: R
# Iter: 995 ; paint: . ; turn: R
# Iter: 996 ; paint: . ; turn: R
# Iter: 997 ; paint: . ; turn: R
# Iter: 998 ; paint: . ; turn: R
# Iter: 999 ; paint: . ; turn: R
# Iter: 1000 ; paint: . ; turn: R
# Iter: 1001 ; paint: . ; turn: R
# Iter: 1002 ; paint: . ; turn: R
# Iter: 1003 ; paint: . ; turn: R
# Iter: 1004 ; paint: . ; turn: R
# Iter: 1005 ; paint: . ; turn: R
# Iter: 1006 ; paint: . ; turn: R
# Iter: 1007 ; paint: . ; turn: R
# Iter: 1008 ; paint: . ; turn: R
# Iter: 1009 ; paint: . ; turn: R
# Iter: 1010 ; paint: . ; turn: R
# Iter: 1011 ; paint: . ; turn: R
# Iter: 1012 ; paint: . ; turn: R
# Iter: 1013 ; paint: . ; turn: R
# Iter: 1014 ; paint: . ; turn: R
# Iter: 1015 ; paint: . ; turn: R
# Iter: 1016 ; paint: . ; turn: R
# Iter: 1017 ; paint: . ; turn: R
# Iter: 1018 ; paint: . ; turn: R
# Iter: 1019 ; paint: . ; turn: R
# Iter: 1020 ; paint: . ; turn: R
# Iter: 1021 ; paint: . ; turn: R
# Iter: 1022 ; paint: . ; turn: R
# Iter: 1023 ; paint: . ; turn: R
# Iter: 1024 ; paint: . ; turn: R
# Iter: 1025 ; paint: . ; turn: R
# Iter: 1026 ; paint: . ; turn: R
# Iter: 1027 ; paint: . ; turn: R
# Iter: 1028 ; paint: . ; turn: R
# Iter: 1029 ; paint: . ; turn: R
# Iter: 1030 ; paint: . ; turn: R
# Iter: 1031 ; paint: . ; turn: R
# Iter: 1032 ; paint: . ; turn: R
# Iter: 1033 ; paint: . ; turn: R
# Iter: 1034 ; paint: . ; turn: R
# Iter: 1035 ; paint: . ; turn: R
# Iter: 1036 ; paint: . ; turn: R
# Iter: 1037 ; paint: . ; turn: R
# Iter: 1038 ; paint: . ; turn: R
# Iter: 1039 ; paint: . ; turn: R
# Iter: 1040 ; paint: . ; turn: R
# Iter: 1041 ; paint: . ; turn: R
# Iter: 1042 ; paint: . ; turn: R
# Iter: 1043 ; paint: . ; turn: R
# Iter: 1044 ; paint: . ; turn: R
# Iter: 1045 ; paint: . ; turn: R
# Iter: 1046 ; paint: . ; turn: R
# Iter: 1047 ; paint: . ; turn: R
# Iter: 1048 ; paint: . ; turn: R
# Iter: 1049 ; paint: . ; turn: R
# Iter: 1050 ; paint: . ; turn: R
# Iter: 1051 ; paint: . ; turn: R
# Iter: 1052 ; paint: . ; turn: R
# Iter: 1053 ; paint: . ; turn: R
# Iter: 1054 ; paint: . ; turn: R
# Iter: 1055 ; paint: . ; turn: R
# Iter: 1056 ; paint: . ; turn: R
# Iter: 1057 ; paint: . ; turn: R
# Iter: 1058 ; paint: . ; turn: R
# Iter: 1059 ; paint: . ; turn: R
# Iter: 1060 ; paint: . ; turn: R
# Iter: 1061 ; paint: . ; turn: R
# Iter: 1062 ; paint: . ; turn: R
# Iter: 1063 ; paint: . ; turn: R
# Iter: 1064 ; paint: . ; turn: R
# Iter: 1065 ; paint: . ; turn: R
# Iter: 1066 ; paint: . ; turn: R
# Iter: 1067 ; paint: . ; turn: R
# Iter: 1068 ; paint: . ; turn: R
# Iter: 1069 ; paint: . ; turn: R
# Iter: 1070 ; paint: . ; turn: R
# Iter: 1071 ; paint: . ; turn: R
# Iter: 1072 ; paint: . ; turn: R
# Iter: 1073 ; paint: . ; turn: R
# Iter: 1074 ; paint: . ; turn: R
# Iter: 1075 ; paint: . ; turn: R
# Iter: 1076 ; paint: . ; turn: R
# Iter: 1077 ; paint: . ; turn: R
# Iter: 1078 ; paint: . ; turn: R
# Iter: 1079 ; paint: . ; turn: R
# Iter: 1080 ; paint: . ; turn: R
# Iter: 1081 ; paint: . ; turn: R
# Iter: 1082 ; paint: . ; turn: R
# Iter: 1083 ; paint: . ; turn: R
# Iter: 1084 ; paint: . ; turn: R
# Iter: 1085 ; paint: . ; turn: R
# Iter: 1086 ; paint: . ; turn: R
# Iter: 1087 ; paint: . ; turn: R
# Iter: 1088 ; paint: . ; turn: R
# Iter: 1089 ; paint: . ; turn: R
# Iter: 1090 ; paint: . ; turn: R
# Iter: 1091 ; paint: . ; turn: R
# Iter: 1092 ; paint: . ; turn: R
# Iter: 1093 ; paint: . ; turn: R
# Iter: 1094 ; paint: . ; turn: R
# Iter: 1095 ; paint: . ; turn: R
# Iter: 1096 ; paint: . ; turn: R
# Iter: 1097 ; paint: . ; turn: R
# Iter: 1098 ; paint: . ; turn: R
# Iter: 1099 ; paint: . ; turn: R
# Iter: 1100 ; paint: . ; turn: R
# Iter: 1101 ; paint: . ; turn: R
# Iter: 1102 ; paint: . ; turn: R
# Iter: 1103 ; paint: . ; turn: R
# Iter: 1104 ; paint: . ; turn: R
# Iter: 1105 ; paint: . ; turn: R
# Iter: 1106 ; paint: . ; turn: R
# Iter: 1107 ; paint: . ; turn: R
# Iter: 1108 ; paint: . ; turn: R
# Iter: 1109 ; paint: . ; turn: R
# Iter: 1110 ; paint: . ; turn: R
# Iter: 1111 ; paint: . ; turn: R
# Iter: 1112 ; paint: . ; turn: R
# Iter: 1113 ; paint: . ; turn: R
# Iter: 1114 ; paint: . ; turn: R
# Iter: 1115 ; paint: . ; turn: R
# Iter: 1116 ; paint: . ; turn: R
# Iter: 1117 ; paint: . ; turn: R
# Iter: 1118 ; paint: . ; turn: R
# Iter: 1119 ; paint: . ; turn: R
# Iter: 1120 ; paint: . ; turn: R
# Iter: 1121 ; paint: . ; turn: R
# Iter: 1122 ; paint: . ; turn: R
# Iter: 1123 ; paint: . ; turn: R
# Iter: 1124 ; paint: . ; turn: R
# Iter: 1125 ; paint: . ; turn: R
# Iter: 1126 ; paint: . ; turn: R
# Iter: 1127 ; paint: . ; turn: R
# Iter: 1128 ; paint: . ; turn: R
# Iter: 1129 ; paint: . ; turn: R
# Iter: 1130 ; paint: . ; turn: R
# Iter: 1131 ; paint: . ; turn: R
# Iter: 1132 ; paint: . ; turn: R
# Iter: 1133 ; paint: . ; turn: R
# Iter: 1134 ; paint: . ; turn: R
# Iter: 1135 ; paint: . ; turn: R
# Iter: 1136 ; paint: . ; turn: R
# Iter: 1137 ; paint: . ; turn: R
# Iter: 1138 ; paint: . ; turn: R
# Iter: 1139 ; paint: . ; turn: R
# Iter: 1140 ; paint: . ; turn: R
# Iter: 1141 ; paint: . ; turn: R
# Iter: 1142 ; paint: . ; turn: R
# Iter: 1143 ; paint: . ; turn: R
# Iter: 1144 ; paint: . ; turn: R
# Iter: 1145 ; paint: . ; turn: R
# Iter: 1146 ; paint: . ; turn: R
# Iter: 1147 ; paint: . ; turn: R
# Iter: 1148 ; paint: . ; turn: R
# Iter: 1149 ; paint: . ; turn: R
# Iter: 1150 ; paint: . ; turn: R
# Iter: 1151 ; paint: . ; turn: R
# Iter: 1152 ; paint: . ; turn: R
# Iter: 1153 ; paint: . ; turn: R
# Iter: 1154 ; paint: . ; turn: R
# Iter: 1155 ; paint: . ; turn: R
# Iter: 1156 ; paint: . ; turn: R
# Iter: 1157 ; paint: . ; turn: R
# Iter: 1158 ; paint: . ; turn: R
# Iter: 1159 ; paint: . ; turn: R
# Iter: 1160 ; paint: . ; turn: R
# Iter: 1161 ; paint: . ; turn: R
# Iter: 1162 ; paint: . ; turn: R
# Iter: 1163 ; paint: . ; turn: R
# Iter: 1164 ; paint: . ; turn: R
# Iter: 1165 ; paint: . ; turn: R
# Iter: 1166 ; paint: . ; turn: R
# Iter: 1167 ; paint: . ; turn: R
# Iter: 1168 ; paint: . ; turn: R
# Iter: 1169 ; paint: . ; turn: R
# Iter: 1170 ; paint: . ; turn: R
# Iter: 1171 ; paint: . ; turn: R
# Iter: 1172 ; paint: . ; turn: R
# Iter: 1173 ; paint: . ; turn: R
# Iter: 1174 ; paint: . ; turn: R
# Iter: 1175 ; paint: . ; turn: R
# Iter: 1176 ; paint: . ; turn: R
# Iter: 1177 ; paint: . ; turn: R
# Iter: 1178 ; paint: . ; turn: R
# Iter: 1179 ; paint: . ; turn: R
# Iter: 1180 ; paint: . ; turn: R
# Iter: 1181 ; paint: . ; turn: R
# Iter: 1182 ; paint: . ; turn: R
# Iter: 1183 ; paint: . ; turn: R
# Iter: 1184 ; paint: . ; turn: R
# Iter: 1185 ; paint: . ; turn: R
# Iter: 1186 ; paint: . ; turn: R
# Iter: 1187 ; paint: . ; turn: R
# Iter: 1188 ; paint: . ; turn: R
# Iter: 1189 ; paint: . ; turn: R
# Iter: 1190 ; paint: . ; turn: R
# Iter: 1191 ; paint: . ; turn: R
# Iter: 1192 ; paint: . ; turn: R
# Iter: 1193 ; paint: . ; turn: R
# Iter: 1194 ; paint: . ; turn: R
# Iter: 1195 ; paint: . ; turn: R
# Iter: 1196 ; paint: . ; turn: R
# Iter: 1197 ; paint: . ; turn: R
# Iter: 1198 ; paint: . ; turn: R
# Iter: 1199 ; paint: . ; turn: R
# Iter: 1200 ; paint: . ; turn: R
# Iter: 1201 ; paint: . ; turn: R
# Iter: 1202 ; paint: . ; turn: R
# Iter: 1203 ; paint: . ; turn: R
# Iter: 1204 ; paint: . ; turn: R
# Iter: 1205 ; paint: . ; turn: R
# Iter: 1206 ; paint: . ; turn: R
# Iter: 1207 ; paint: . ; turn: R
# Iter: 1208 ; paint: . ; turn: R
# Iter: 1209 ; paint: . ; turn: R
# Iter: 1210 ; paint: . ; turn: R
# Iter: 1211 ; paint: . ; turn: R
# Iter: 1212 ; paint: . ; turn: R
# Iter: 1213 ; paint: . ; turn: R
# Iter: 1214 ; paint: . ; turn: R
# Iter: 1215 ; paint: . ; turn: R
# Iter: 1216 ; paint: . ; turn: R
# Iter: 1217 ; paint: . ; turn: R
# Iter: 1218 ; paint: . ; turn: R
# Iter: 1219 ; paint: . ; turn: R
# Iter: 1220 ; paint: . ; turn: R
# Iter: 1221 ; paint: . ; turn: R
# Iter: 1222 ; paint: . ; turn: R
# Iter: 1223 ; paint: . ; turn: R
# Iter: 1224 ; paint: . ; turn: R
# Iter: 1225 ; paint: . ; turn: R
# Iter: 1226 ; paint: . ; turn: R
# Iter: 1227 ; paint: . ; turn: R
# Iter: 1228 ; paint: . ; turn: R
# Iter: 1229 ; paint: . ; turn: R
# Iter: 1230 ; paint: . ; turn: R
# Iter: 1231 ; paint: . ; turn: R
# Iter: 1232 ; paint: . ; turn: R
# Iter: 1233 ; paint: . ; turn: R
# Iter: 1234 ; paint: . ; turn: R
# Iter: 1235 ; paint: . ; turn: R
# Iter: 1236 ; paint: . ; turn: R
# Iter: 1237 ; paint: . ; turn: R
# Iter: 1238 ; paint: . ; turn: R
# Iter: 1239 ; paint: . ; turn: R
# Iter: 1240 ; paint: . ; turn: R
# Iter: 1241 ; paint: . ; turn: R
# Iter: 1242 ; paint: . ; turn: R
# Iter: 1243 ; paint: . ; turn: R
# Iter: 1244 ; paint: . ; turn: R
# Iter: 1245 ; paint: . ; turn: R
# Iter: 1246 ; paint: . ; turn: R
# Iter: 1247 ; paint: . ; turn: R
# Iter: 1248 ; paint: . ; turn: R
# Iter: 1249 ; paint: . ; turn: R
# Iter: 1250 ; paint: . ; turn: R
# Iter: 1251 ; paint: . ; turn: R
# Iter: 1252 ; paint: . ; turn: R
# Iter: 1253 ; paint: . ; turn: R
# Iter: 1254 ; paint: . ; turn: R
# Iter: 1255 ; paint: . ; turn: R
# Iter: 1256 ; paint: . ; turn: R
# Iter: 1257 ; paint: . ; turn: R
# Iter: 1258 ; paint: . ; turn: R
# Iter: 1259 ; paint: . ; turn: R
# Iter: 1260 ; paint: . ; turn: R
# Iter: 1261 ; paint: . ; turn: R
# Iter: 1262 ; paint: . ; turn: R
# Iter: 1263 ; paint: . ; turn: R
# Iter: 1264 ; paint: . ; turn: R
# Iter: 1265 ; paint: . ; turn: R
# Iter: 1266 ; paint: . ; turn: R
# Iter: 1267 ; paint: . ; turn: R
# Iter: 1268 ; paint: . ; turn: R
# Iter: 1269 ; paint: . ; turn: R
# Iter: 1270 ; paint: . ; turn: R
# Iter: 1271 ; paint: . ; turn: R
# Iter: 1272 ; paint: . ; turn: R
# Iter: 1273 ; paint: . ; turn: R
# Iter: 1274 ; paint: . ; turn: R
# Iter: 1275 ; paint: . ; turn: R
# Iter: 1276 ; paint: . ; turn: R
# Iter: 1277 ; paint: . ; turn: R
# Iter: 1278 ; paint: . ; turn: R
# Iter: 1279 ; paint: . ; turn: R
# Iter: 1280 ; paint: . ; turn: R
# Iter: 1281 ; paint: . ; turn: R
# Iter: 1282 ; paint: . ; turn: R
# Iter: 1283 ; paint: . ; turn: R
# Iter: 1284 ; paint: . ; turn: R
# Iter: 1285 ; paint: . ; turn: R
# Iter: 1286 ; paint: . ; turn: R
# Iter: 1287 ; paint: . ; turn: R
# Iter: 1288 ; paint: . ; turn: R
# Iter: 1289 ; paint: . ; turn: R
# Iter: 1290 ; paint: . ; turn: R
# Iter: 1291 ; paint: . ; turn: R
# Iter: 1292 ; paint: . ; turn: R
# Iter: 1293 ; paint: . ; turn: R
# Iter: 1294 ; paint: . ; turn: R
# Iter: 1295 ; paint: . ; turn: R
# Iter: 1296 ; paint: . ; turn: R
# Iter: 1297 ; paint: . ; turn: R
# Iter: 1298 ; paint: . ; turn: R
# Iter: 1299 ; paint: . ; turn: R
# Iter: 1300 ; paint: . ; turn: R
# Iter: 1301 ; paint: . ; turn: R
# Iter: 1302 ; paint: . ; turn: R
# Iter: 1303 ; paint: . ; turn: R
# Iter: 1304 ; paint: . ; turn: R
# Iter: 1305 ; paint: . ; turn: R
# Iter: 1306 ; paint: . ; turn: R
# Iter: 1307 ; paint: . ; turn: R
# Iter: 1308 ; paint: . ; turn: R
# Iter: 1309 ; paint: . ; turn: R
# Iter: 1310 ; paint: . ; turn: R
# Iter: 1311 ; paint: . ; turn: R
# Iter: 1312 ; paint: . ; turn: R
# Iter: 1313 ; paint: . ; turn: R
# Iter: 1314 ; paint: . ; turn: R
# Iter: 1315 ; paint: . ; turn: R
# Iter: 1316 ; paint: . ; turn: R
# Iter: 1317 ; paint: . ; turn: R
# Iter: 1318 ; paint: . ; turn: R
# Iter: 1319 ; paint: . ; turn: R
# Iter: 1320 ; paint: . ; turn: R
# Iter: 1321 ; paint: . ; turn: R
# Iter: 1322 ; paint: . ; turn: R
# Iter: 1323 ; paint: . ; turn: R
# Iter: 1324 ; paint: . ; turn: R
# Iter: 1325 ; paint: . ; turn: R
# Iter: 1326 ; paint: . ; turn: R
# Iter: 1327 ; paint: . ; turn: R
# Iter: 1328 ; paint: . ; turn: R
# Iter: 1329 ; paint: . ; turn: R
# Iter: 1330 ; paint: . ; turn: R
# Iter: 1331 ; paint: . ; turn: R
# Iter: 1332 ; paint: . ; turn: R
# Iter: 1333 ; paint: . ; turn: R
# Iter: 1334 ; paint: . ; turn: R
# Iter: 1335 ; paint: . ; turn: R
# Iter: 1336 ; paint: . ; turn: R
# Iter: 1337 ; paint: . ; turn: R
# Iter: 1338 ; paint: . ; turn: R
# Iter: 1339 ; paint: . ; turn: R
# Iter: 1340 ; paint: . ; turn: R
# Iter: 1341 ; paint: . ; turn: R
# Iter: 1342 ; paint: . ; turn: R
# Iter: 1343 ; paint: . ; turn: R
# Iter: 1344 ; paint: . ; turn: R
# Iter: 1345 ; paint: . ; turn: R
# Iter: 1346 ; paint: . ; turn: R
# Iter: 1347 ; paint: . ; turn: R
# Iter: 1348 ; paint: . ; turn: R
# Iter: 1349 ; paint: . ; turn: R
# Iter: 1350 ; paint: . ; turn: R
# Iter: 1351 ; paint: . ; turn: R
# Iter: 1352 ; paint: . ; turn: R
# Iter: 1353 ; paint: . ; turn: R
# Iter: 1354 ; paint: . ; turn: R
# Iter: 1355 ; paint: . ; turn: R
# Iter: 1356 ; paint: . ; turn: R
# Iter: 1357 ; paint: . ; turn: R
# Iter: 1358 ; paint: . ; turn: R
# Iter: 1359 ; paint: . ; turn: R
# Iter: 1360 ; paint: . ; turn: R
# Iter: 1361 ; paint: . ; turn: R
# Iter: 1362 ; paint: . ; turn: R
# Iter: 1363 ; paint: . ; turn: R
# Iter: 1364 ; paint: . ; turn: R
# Iter: 1365 ; paint: . ; turn: R
# Iter: 1366 ; paint: . ; turn: R
# Iter: 1367 ; paint: . ; turn: R
# Iter: 1368 ; paint: . ; turn: R
# Iter: 1369 ; paint: . ; turn: R
# Iter: 1370 ; paint: . ; turn: R
# Iter: 1371 ; paint: . ; turn: R
# Iter: 1372 ; paint: . ; turn: R
# Iter: 1373 ; paint: . ; turn: R
# Iter: 1374 ; paint: . ; turn: R
# Iter: 1375 ; paint: . ; turn: R
# Iter: 1376 ; paint: . ; turn: R
# Iter: 1377 ; paint: . ; turn: R
# Iter: 1378 ; paint: . ; turn: R
# Iter: 1379 ; paint: . ; turn: R
# Iter: 1380 ; paint: . ; turn: R
# Iter: 1381 ; paint: . ; turn: R
# Iter: 1382 ; paint: . ; turn: R
# Iter: 1383 ; paint: . ; turn: R
# Iter: 1384 ; paint: . ; turn: R
# Iter: 1385 ; paint: . ; turn: R
# Iter: 1386 ; paint: . ; turn: R
# Iter: 1387 ; paint: . ; turn: R
# Iter: 1388 ; paint: . ; turn: R
# Iter: 1389 ; paint: . ; turn: R
# Iter: 1390 ; paint: . ; turn: R
# Iter: 1391 ; paint: . ; turn: R
# Iter: 1392 ; paint: . ; turn: R
# Iter: 1393 ; paint: . ; turn: R
# Iter: 1394 ; paint: . ; turn: R
# Iter: 1395 ; paint: . ; turn: R
# Iter: 1396 ; paint: . ; turn: R
# Iter: 1397 ; paint: . ; turn: R
# Iter: 1398 ; paint: . ; turn: R
# Iter: 1399 ; paint: . ; turn: R
# Iter: 1400 ; paint: . ; turn: R
# Iter: 1401 ; paint: . ; turn: R
# Iter: 1402 ; paint: . ; turn: R
# Iter: 1403 ; paint: . ; turn: R
# Iter: 1404 ; paint: . ; turn: R
# Iter: 1405 ; paint: . ; turn: R
# Iter: 1406 ; paint: . ; turn: R
# Iter: 1407 ; paint: . ; turn: R
# Iter: 1408 ; paint: . ; turn: R
# Iter: 1409 ; paint: . ; turn: R
# Iter: 1410 ; paint: . ; turn: R
# Iter: 1411 ; paint: . ; turn: R
# Iter: 1412 ; paint: . ; turn: R
# Iter: 1413 ; paint: . ; turn: R
# Iter: 1414 ; paint: . ; turn: R
# Iter: 1415 ; paint: . ; turn: R
# Iter: 1416 ; paint: . ; turn: R
# Iter: 1417 ; paint: . ; turn: R
# Iter: 1418 ; paint: . ; turn: R
# Iter: 1419 ; paint: . ; turn: R
# Iter: 1420 ; paint: . ; turn: R
# Iter: 1421 ; paint: . ; turn: R
# Iter: 1422 ; paint: . ; turn: R
# Iter: 1423 ; paint: . ; turn: R
# Iter: 1424 ; paint: . ; turn: R
# Iter: 1425 ; paint: . ; turn: R
# Iter: 1426 ; paint: . ; turn: R
# Iter: 1427 ; paint: . ; turn: R
# Iter: 1428 ; paint: . ; turn: R
# Iter: 1429 ; paint: . ; turn: R
# Iter: 1430 ; paint: . ; turn: R
# Iter: 1431 ; paint: . ; turn: R
# Iter: 1432 ; paint: . ; turn: R
# Iter: 1433 ; paint: . ; turn: R
# Iter: 1434 ; paint: . ; turn: R
# Iter: 1435 ; paint: . ; turn: R
# Iter: 1436 ; paint: . ; turn: R
# Iter: 1437 ; paint: . ; turn: R
# Iter: 1438 ; paint: . ; turn: R
# Iter: 1439 ; paint: . ; turn: R
# Iter: 1440 ; paint: . ; turn: R
# Iter: 1441 ; paint: . ; turn: R
# Iter: 1442 ; paint: . ; turn: R
# Iter: 1443 ; paint: . ; turn: R
# Iter: 1444 ; paint: . ; turn: R
# Iter: 1445 ; paint: . ; turn: R
# Iter: 1446 ; paint: . ; turn: R
# Iter: 1447 ; paint: . ; turn: R
# Iter: 1448 ; paint: . ; turn: R
# Iter: 1449 ; paint: . ; turn: R
# Iter: 1450 ; paint: . ; turn: R
# Iter: 1451 ; paint: . ; turn: R
# Iter: 1452 ; paint: . ; turn: R
# Iter: 1453 ; paint: . ; turn: R
# Iter: 1454 ; paint: . ; turn: R
# Iter: 1455 ; paint: . ; turn: R
# Iter: 1456 ; paint: . ; turn: R
# Iter: 1457 ; paint: . ; turn: R
# Iter: 1458 ; paint: . ; turn: R
# Iter: 1459 ; paint: . ; turn: R
# Iter: 1460 ; paint: . ; turn: R
# Iter: 1461 ; paint: . ; turn: R
# Iter: 1462 ; paint: . ; turn: R
# Iter: 1463 ; paint: . ; turn: R
# Iter: 1464 ; paint: . ; turn: R
# Iter: 1465 ; paint: . ; turn: R
# Iter: 1466 ; paint: . ; turn: R
# Iter: 1467 ; paint: . ; turn: R
# Iter: 1468 ; paint: . ; turn: R
# Iter: 1469 ; paint: . ; turn: R
# Iter: 1470 ; paint: . ; turn: R
# Iter: 1471 ; paint: . ; turn: R
# Iter: 1472 ; paint: . ; turn: R
# Iter: 1473 ; paint: . ; turn: R
# Iter: 1474 ; paint: . ; turn: R
# Iter: 1475 ; paint: . ; turn: R
# Iter: 1476 ; paint: . ; turn: R
# Iter: 1477 ; paint: . ; turn: R
# Iter: 1478 ; paint: . ; turn: R
# Iter: 1479 ; paint: . ; turn: R
# Iter: 1480 ; paint: . ; turn: R
# Iter: 1481 ; paint: . ; turn: R
# Iter: 1482 ; paint: . ; turn: R
# Iter: 1483 ; paint: . ; turn: R
# Iter: 1484 ; paint: . ; turn: R
# Iter: 1485 ; paint: . ; turn: R
# Iter: 1486 ; paint: . ; turn: R
# Iter: 1487 ; paint: . ; turn: R
# Iter: 1488 ; paint: . ; turn: R
# Iter: 1489 ; paint: . ; turn: R
# Iter: 1490 ; paint: . ; turn: R
# Iter: 1491 ; paint: . ; turn: R
# Iter: 1492 ; paint: . ; turn: R
# Iter: 1493 ; paint: . ; turn: R
# Iter: 1494 ; paint: . ; turn: R
# Iter: 1495 ; paint: . ; turn: R
# Iter: 1496 ; paint: . ; turn: R
# Iter: 1497 ; paint: . ; turn: R
# Iter: 1498 ; paint: . ; turn: R
# Iter: 1499 ; paint: . ; turn: R
# Iter: 1500 ; paint: . ; turn: R
# Iter: 1501 ; paint: . ; turn: R
# Iter: 1502 ; paint: . ; turn: R
# Iter: 1503 ; paint: . ; turn: R
# Iter: 1504 ; paint: . ; turn: R
# Iter: 1505 ; paint: . ; turn: R
# Iter: 1506 ; paint: . ; turn: R
# Iter: 1507 ; paint: . ; turn: R
# Iter: 1508 ; paint: . ; turn: R
# Iter: 1509 ; paint: . ; turn: R
# Iter: 1510 ; paint: . ; turn: R
# Iter: 1511 ; paint: . ; turn: R
# Iter: 1512 ; paint: . ; turn: R
# Iter: 1513 ; paint: . ; turn: R
# Iter: 1514 ; paint: . ; turn: R
# Iter: 1515 ; paint: . ; turn: R
# Iter: 1516 ; paint: . ; turn: R
# Iter: 1517 ; paint: . ; turn: R
# Iter: 1518 ; paint: . ; turn: R
# Iter: 1519 ; paint: . ; turn: R
# Iter: 1520 ; paint: . ; turn: R
# Iter: 1521 ; paint: . ; turn: R
# Iter: 1522 ; paint: . ; turn: R
# Iter: 1523 ; paint: . ; turn: R
# Iter: 1524 ; paint: . ; turn: R
# Iter: 1525 ; paint: . ; turn: R
# Iter: 1526 ; paint: . ; turn: R
# Iter: 1527 ; paint: . ; turn: R
# Iter: 1528 ; paint: . ; turn: R
# Iter: 1529 ; paint: . ; turn: R
# Iter: 1530 ; paint: . ; turn: R
# Iter: 1531 ; paint: . ; turn: R
# Iter: 1532 ; paint: . ; turn: R
# Iter: 1533 ; paint: . ; turn: R
# Iter: 1534 ; paint: . ; turn: R
# ...
# Iter: 1967 ; paint: . ; turn: R
# Iter: 1968 ; paint: . ; turn: R
# Iter: 1969 ; paint: . ; turn: R
# Iter: 1970 ; paint: . ; turn: R
# Iter: 1971 ; paint: . ; turn: R
# Iter: 1972 ; paint: . ; turn: R
# Iter: 1973 ; paint: . ; turn: R
# Iter: 1974 ; paint: . ; turn: R
# Iter: 1975 ; paint: . ; turn: R
# Iter: 1976 ; paint: . ; turn: R
# Iter: 1977 ; paint: . ; turn: R
# Iter: 1978 ; paint: . ; turn: R
# Iter: 1979 ; paint: . ; turn: R
# Iter: 1980 ; paint: . ; turn: R
# Iter: 1981 ; paint: . ; turn: R
# Iter: 1982 ; paint: . ; turn: R
# Iter: 1983 ; paint: . ; turn: R
# Iter: 1984 ; paint: . ; turn: R
# Iter: 1985 ; paint: . ; turn: R
# Iter: 1986 ; paint: . ; turn: R
# Iter: 1987 ; paint: . ; turn: R
# Iter: 1988 ; paint: . ; turn: R
# Iter: 1989 ; paint: . ; turn: R
# Iter: 1990 ; paint: . ; turn: R
# Iter: 1991 ; paint: . ; turn: R
# Iter: 1992 ; paint: . ; turn: R
# Iter: 1993 ; paint: . ; turn: R
# Iter: 1994 ; paint: . ; turn: R
# Iter: 1995 ; paint: . ; turn: R
# Iter: 1996 ; paint: . ; turn: R
# Iter: 1997 ; paint: . ; turn: R
# Iter: 1998 ; paint: . ; turn: R
# Iter: 1999 ; paint: . ; turn: R
# Iter: 2000 ; paint: . ; turn: R
# Iter: 2001 ; paint: . ; turn: R
# Iter: 2002 ; paint: . ; turn: R
# Iter: 2003 ; paint: . ; turn: R
# Iter: 2004 ; paint: . ; turn: R
# Iter: 2005 ; paint: . ; turn: R
# Iter: 2006 ; paint: . ; turn: R
# Iter: 2007 ; paint: . ; turn: R
# Iter: 2008 ; paint: . ; turn: R
# Iter: 2009 ; paint: . ; turn: R
# Iter: 2010 ; paint: . ; turn: R
# Iter: 2011 ; paint: . ; turn: R
# Iter: 2012 ; paint: . ; turn: R
# Iter: 2013 ; paint: . ; turn: R
# Iter: 2014 ; paint: . ; turn: R
# Iter: 2015 ; paint: . ; turn: R
# Iter: 2016 ; paint: . ; turn: R
# Iter: 2017 ; paint: . ; turn: R
# Iter: 2018 ; paint: . ; turn: R
# Iter: 2019 ; paint: . ; turn: R
# Iter: 2020 ; paint: . ; turn: R
# Iter: 2021 ; paint: . ; turn: R
# Iter: 2022 ; paint: . ; turn: R
# Iter: 2023 ; paint: . ; turn: R
# Iter: 2024 ; paint: . ; turn: R
# Iter: 2025 ; paint: . ; turn: R
# Iter: 2026 ; paint: . ; turn: R
# Iter: 2027 ; paint: . ; turn: R
# Iter: 2028 ; paint: . ; turn: R
# Iter: 2029 ; paint: . ; turn: R
# Iter: 2030 ; paint: . ; turn: R
# Iter: 2031 ; paint: . ; turn: R
# Iter: 2032 ; paint: . ; turn: R
# Iter: 2033 ; paint: . ; turn: R
# Iter: 2034 ; paint: . ; turn: R
# Iter: 2035 ; paint: . ; turn: R
# Iter: 2036 ; paint: . ; turn: R
# Iter: 2037 ; paint: . ; turn: R
# Iter: 2038 ; paint: . ; turn: R
# Iter: 2039 ; paint: . ; turn: R
# Iter: 2040 ; paint: . ; turn: R
# Iter: 2041 ; paint: . ; turn: R
# Iter: 2042 ; paint: . ; turn: R
# Iter: 2043 ; paint: . ; turn: R
# Iter: 2044 ; paint: . ; turn: R
# Iter: 2045 ; paint: . ; turn: R
# Iter: 2046 ; paint: . ; turn: R
# Iter: 2047 ; paint: . ; turn: R
# Iter: 2048 ; paint: . ; turn: R
# Iter: 2049 ; paint: . ; turn: R
# Iter: 2050 ; paint: . ; turn: R
# Iter: 2051 ; paint: . ; turn: R
# Iter: 2052 ; paint: . ; turn: R
# Iter: 2053 ; paint: . ; turn: R
# Iter: 2054 ; paint: . ; turn: R
# Iter: 2055 ; paint: . ; turn: R
# Iter: 2056 ; paint: . ; turn: R
# Iter: 2057 ; paint: . ; turn: R
# Iter: 2058 ; paint: . ; turn: R
# Iter: 2059 ; paint: . ; turn: R
# Iter: 2060 ; paint: . ; turn: R
# Iter: 2061 ; paint: . ; turn: R
# Iter: 2062 ; paint: . ; turn: R
# Iter: 2063 ; paint: . ; turn: R
# Iter: 2064 ; paint: . ; turn: R
# Iter: 2065 ; paint: . ; turn: R
# Iter: 2066 ; paint: . ; turn: R
# Iter: 2067 ; paint: . ; turn: R
# Iter: 2068 ; paint: . ; turn: R
# Iter: 2069 ; paint: . ; turn: R
# Iter: 2070 ; paint: . ; turn: R
# Iter: 2071 ; paint: . ; turn: R
# Iter: 2072 ; paint: . ; turn: R
# Iter: 2073 ; paint: . ; turn: R
# Iter: 2074 ; paint: . ; turn: R
# Iter: 2075 ; paint: . ; turn: R
# Iter: 2076 ; paint: . ; turn: R
# Iter: 2077 ; paint: . ; turn: R
# Iter: 2078 ; paint: . ; turn: R
# Iter: 2079 ; paint: . ; turn: R
# Iter: 2080 ; paint: . ; turn: R
# Iter: 2081 ; paint: . ; turn: R
# Iter: 2082 ; paint: . ; turn: R
# Iter: 2083 ; paint: . ; turn: R
# Iter: 2084 ; paint: . ; turn: R
# Iter: 2085 ; paint: . ; turn: R
# Iter: 2086 ; paint: . ; turn: R
# Iter: 2087 ; paint: . ; turn: R
# Iter: 2088 ; paint: . ; turn: R
# Iter: 2089 ; paint: . ; turn: R
# Iter: 2090 ; paint: . ; turn: R
# Iter: 2091 ; paint: . ; turn: R
# Iter: 2092 ; paint: . ; turn: R
# Iter: 2093 ; paint: . ; turn: R
# Iter: 2094 ; paint: . ; turn: R
# Iter: 2095 ; paint: . ; turn: R
# Iter: 2096 ; paint: . ; turn: R
# Iter: 2097 ; paint: . ; turn: R
# Iter: 2098 ; paint: . ; turn: R
# Iter: 2099 ; paint: . ; turn: R
# Iter: 2100 ; paint: . ; turn: R
# Iter: 2101 ; paint: . ; turn: R
# Iter: 2102 ; paint: . ; turn: R
# Iter: 2103 ; paint: . ; turn: R
# Iter: 2104 ; paint: . ; turn: R
# Iter: 2105 ; paint: . ; turn: R
# Iter: 2106 ; paint: . ; turn: R
# Iter: 2107 ; paint: . ; turn: R
# Iter: 2108 ; paint: . ; turn: R
# Iter: 2109 ; paint: . ; turn: R
# Iter: 2110 ; paint: . ; turn: R
# Iter: 2111 ; paint: . ; turn: R
# Iter: 2112 ; paint: . ; turn: R
# Iter: 2113 ; paint: . ; turn: R
# Iter: 2114 ; paint: . ; turn: R
# Iter: 2115 ; paint: . ; turn: R
# Iter: 2116 ; paint: . ; turn: R
# Iter: 2117 ; paint: . ; turn: R
# Iter: 2118 ; paint: . ; turn: R
# Iter: 2119 ; paint: . ; turn: R
# Iter: 2120 ; paint: . ; turn: R
# Iter: 2121 ; paint: . ; turn: R
# Iter: 2122 ; paint: . ; turn: R
# Iter: 2123 ; paint: . ; turn: R
# Iter: 2124 ; paint: . ; turn: R
# Iter: 2125 ; paint: . ; turn: R
# Iter: 2126 ; paint: . ; turn: R
# Iter: 2127 ; paint: . ; turn: R
# Iter: 2128 ; paint: . ; turn: R
# Iter: 2129 ; paint: . ; turn: R
# Iter: 2130 ; paint: . ; turn: R
# Iter: 2131 ; paint: . ; turn: R
# Iter: 2132 ; paint: . ; turn: R
# Iter: 2133 ; paint: . ; turn: R
# Iter: 2134 ; paint: . ; turn: R
# Iter: 2135 ; paint: . ; turn: R
# Iter: 2136 ; paint: . ; turn: R
# Iter: 2137 ; paint: . ; turn: R
# Iter: 2138 ; paint: . ; turn: R
# Iter: 2139 ; paint: . ; turn: R
# Iter: 2140 ; paint: . ; turn: R
# Iter: 2141 ; paint: . ; turn: R
# Iter: 2142 ; paint: . ; turn: R
# Iter: 2143 ; paint: . ; turn: R
# Iter: 2144 ; paint: . ; turn: R
# Iter: 2145 ; paint: . ; turn: R
# Iter: 2146 ; paint: . ; turn: R
# Iter: 2147 ; paint: . ; turn: R
# Iter: 2148 ; paint: . ; turn: R
# Iter: 2149 ; paint: . ; turn: R
# Iter: 2150 ; paint: . ; turn: R
# Iter: 2151 ; paint: . ; turn: R
# Iter: 2152 ; paint: . ; turn: R
# Iter: 2153 ; paint: . ; turn: R
# Iter: 2154 ; paint: . ; turn: R
# Iter: 2155 ; paint: . ; turn: R
# Iter: 2156 ; paint: . ; turn: R
# Iter: 2157 ; paint: . ; turn: R
# Iter: 2158 ; paint: . ; turn: R
# Iter: 2159 ; paint: . ; turn: R
# Iter: 2160 ; paint: . ; turn: R
# Iter: 2161 ; paint: . ; turn: R
# Iter: 2162 ; paint: . ; turn: R
# Iter: 2163 ; paint: . ; turn: R
# Iter: 2164 ; paint: . ; turn: R
# Iter: 2165 ; paint: . ; turn: R
# Iter: 2166 ; paint: . ; turn: R
# Iter: 2167 ; paint: . ; turn: R
# Iter: 2168 ; paint: . ; turn: R
# Iter: 2169 ; paint: . ; turn: R
# Iter: 2170 ; paint: . ; turn: R
# Iter: 2171 ; paint: . ; turn: R
# Iter: 2172 ; paint: . ; turn: R
# Iter: 2173 ; paint: . ; turn: R
# Iter: 2174 ; paint: . ; turn: R
# Iter: 2175 ; paint: . ; turn: R
# Iter: 2176 ; paint: . ; turn: R
# Iter: 2177 ; paint: . ; turn: R
# Iter: 2178 ; paint: . ; turn: R
# Iter: 2179 ; paint: . ; turn: R
# Iter: 2180 ; paint: . ; turn: R
# Iter: 2181 ; paint: . ; turn: R
# Iter: 2182 ; paint: . ; turn: R
# Iter: 2183 ; paint: . ; turn: R
# Iter: 2184 ; paint: . ; turn: R
# Iter: 2185 ; paint: . ; turn: R
# Iter: 2186 ; paint: . ; turn: R
# Iter: 2187 ; paint: . ; turn: R
# Iter: 2188 ; paint: . ; turn: R
# Iter: 2189 ; paint: . ; turn: R
# Iter: 2190 ; paint: . ; turn: R
# Iter: 2191 ; paint: . ; turn: R
# Iter: 2192 ; paint: . ; turn: R
# Iter: 2193 ; paint: . ; turn: R
# Iter: 2194 ; paint: . ; turn: R
# Iter: 2195 ; paint: . ; turn: R
# Iter: 2196 ; paint: . ; turn: R
# Iter: 2197 ; paint: . ; turn: R
# Iter: 2198 ; paint: . ; turn: R
# Iter: 2199 ; paint: . ; turn: R
# Iter: 2200 ; paint: . ; turn: R
# Iter: 2201 ; paint: . ; turn: R
# Iter: 2202 ; paint: . ; turn: R
# Iter: 2203 ; paint: . ; turn: R
# Iter: 2204 ; paint: . ; turn: R
# Iter: 2205 ; paint: . ; turn: R
# Iter: 2206 ; paint: . ; turn: R
# Iter: 2207 ; paint: . ; turn: R
# Iter: 2208 ; paint: . ; turn: R
# Iter: 2209 ; paint: . ; turn: R
# Iter: 2210 ; paint: . ; turn: R
# Iter: 2211 ; paint: . ; turn: R
# Iter: 2212 ; paint: . ; turn: R
# Iter: 2213 ; paint: . ; turn: R
# Iter: 2214 ; paint: . ; turn: R
# Iter: 2215 ; paint: . ; turn: R
# Iter: 2216 ; paint: . ; turn: R
# Iter: 2217 ; paint: . ; turn: R
# Iter: 2218 ; paint: . ; turn: R
# Iter: 2219 ; paint: . ; turn: R
# Iter: 2220 ; paint: . ; turn: R
# Iter: 2221 ; paint: . ; turn: R
# Iter: 2222 ; paint: . ; turn: R
# Iter: 2223 ; paint: . ; turn: R
# Iter: 2224 ; paint: . ; turn: R
# Iter: 2225 ; paint: . ; turn: R
# Iter: 2226 ; paint: . ; turn: R
# Iter: 2227 ; paint: . ; turn: R
# Iter: 2228 ; paint: . ; turn: R
# Iter: 2229 ; paint: . ; turn: R
# Iter: 2230 ; paint: . ; turn: R
# Iter: 2231 ; paint: . ; turn: R
# Iter: 2232 ; paint: . ; turn: R
# Iter: 2233 ; paint: . ; turn: R
# Iter: 2234 ; paint: . ; turn: R
# Iter: 2235 ; paint: . ; turn: R
# Iter: 2236 ; paint: . ; turn: R
# Iter: 2237 ; paint: . ; turn: R
# Iter: 2238 ; paint: . ; turn: R
# Iter: 2239 ; paint: . ; turn: R
# Iter: 2240 ; paint: . ; turn: R
# Iter: 2241 ; paint: . ; turn: R
# Iter: 2242 ; paint: . ; turn: R
# Iter: 2243 ; paint: . ; turn: R
# Iter: 2244 ; paint: . ; turn: R
# Iter: 2245 ; paint: . ; turn: R
# Iter: 2246 ; paint: . ; turn: R
# Iter: 2247 ; paint: . ; turn: R
# Iter: 2248 ; paint: . ; turn: R
# Iter: 2249 ; paint: . ; turn: R
# Iter: 2250 ; paint: . ; turn: R
# Iter: 2251 ; paint: . ; turn: R
# Iter: 2252 ; paint: . ; turn: R
# Iter: 2253 ; paint: . ; turn: R
# Iter: 2254 ; paint: . ; turn: R
# Iter: 2255 ; paint: . ; turn: R
# Iter: 2256 ; paint: . ; turn: R
# Iter: 2257 ; paint: . ; turn: R
# Iter: 2258 ; paint: . ; turn: R
# Iter: 2259 ; paint: . ; turn: R
# Iter: 2260 ; paint: . ; turn: R
# Iter: 2261 ; paint: . ; turn: R
# Iter: 2262 ; paint: . ; turn: R
# Iter: 2263 ; paint: . ; turn: R
# Iter: 2264 ; paint: . ; turn: R
# Iter: 2265 ; paint: . ; turn: R
# Iter: 2266 ; paint: . ; turn: R
# Iter: 2267 ; paint: . ; turn: R
# Iter: 2268 ; paint: . ; turn: R
# Iter: 2269 ; paint: . ; turn: R
# Iter: 2270 ; paint: . ; turn: R
# Iter: 2271 ; paint: . ; turn: R
# Iter: 2272 ; paint: . ; turn: R
# Iter: 2273 ; paint: . ; turn: R
# Iter: 2274 ; paint: . ; turn: R
# Iter: 2275 ; paint: . ; turn: R
# Iter: 2276 ; paint: . ; turn: R
# Iter: 2277 ; paint: . ; turn: R
# Iter: 2278 ; paint: . ; turn: R
# Iter: 2279 ; paint: . ; turn: R
# Iter: 2280 ; paint: . ; turn: R
# Iter: 2281 ; paint: . ; turn: R
# Iter: 2282 ; paint: . ; turn: R
# Iter: 2283 ; paint: . ; turn: R
# Iter: 2284 ; paint: . ; turn: R
# Iter: 2285 ; paint: . ; turn: R
# Iter: 2286 ; paint: . ; turn: R
# Iter: 2287 ; paint: . ; turn: R
# Iter: 2288 ; paint: . ; turn: R
# Iter: 2289 ; paint: . ; turn: R
# Iter: 2290 ; paint: . ; turn: R
# Iter: 2291 ; paint: . ; turn: R
# Iter: 2292 ; paint: . ; turn: R
# Iter: 2293 ; paint: . ; turn: R
# Iter: 2294 ; paint: . ; turn: R
# Iter: 2295 ; paint: . ; turn: R
# Iter: 2296 ; paint: . ; turn: R
# Iter: 2297 ; paint: . ; turn: R
# Iter: 2298 ; paint: . ; turn: R
# Iter: 2299 ; paint: . ; turn: R
# Iter: 2300 ; paint: . ; turn: R
# Iter: 2301 ; paint: . ; turn: R
# Iter: 2302 ; paint: . ; turn: R
# Iter: 2303 ; paint: . ; turn: R
# Iter: 2304 ; paint: . ; turn: R
# Iter: 2305 ; paint: . ; turn: R
# Iter: 2306 ; paint: . ; turn: R
# Iter: 2307 ; paint: . ; turn: R
# Iter: 2308 ; paint: . ; turn: R
# Iter: 2309 ; paint: . ; turn: R
# Iter: 2310 ; paint: . ; turn: R
# Iter: 2311 ; paint: . ; turn: R
# Iter: 2312 ; paint: . ; turn: R
# Iter: 2313 ; paint: . ; turn: R
# Iter: 2314 ; paint: . ; turn: R
# Iter: 2315 ; paint: . ; turn: R
# Iter: 2316 ; paint: . ; turn: R
# Iter: 2317 ; paint: . ; turn: R
# Iter: 2318 ; paint: . ; turn: R
# Iter: 2319 ; paint: . ; turn: R
# Iter: 2320 ; paint: . ; turn: R
# Iter: 2321 ; paint: . ; turn: R
# Iter: 2322 ; paint: . ; turn: R
# Iter: 2323 ; paint: . ; turn: R
# Iter: 2324 ; paint: . ; turn: R
# Iter: 2325 ; paint: . ; turn: R
# Iter: 2326 ; paint: . ; turn: R
# Iter: 2327 ; paint: . ; turn: R
# Iter: 2328 ; paint: . ; turn: R
# Iter: 2329 ; paint: . ; turn: R
# Iter: 2330 ; paint: . ; turn: R
# Iter: 2331 ; paint: . ; turn: R
# Iter: 2332 ; paint: . ; turn: R
# Iter: 2333 ; paint: . ; turn: R
# Iter: 2334 ; paint: . ; turn: R
# Iter: 2335 ; paint: . ; turn: R
# Iter: 2336 ; paint: . ; turn: R
# Iter: 2337 ; paint: . ; turn: R
# Iter: 2338 ; paint: . ; turn: R
# Iter: 2339 ; paint: . ; turn: R
# Iter: 2340 ; paint: . ; turn: R
# Iter: 2341 ; paint: . ; turn: R
# Iter: 2342 ; paint: . ; turn: R
# Iter: 2343 ; paint: . ; turn: R
# Iter: 2344 ; paint: . ; turn: R
# Iter: 2345 ; paint: . ; turn: R
# Iter: 2346 ; paint: . ; turn: R
# Iter: 2347 ; paint: . ; turn: R
# Iter: 2348 ; paint: . ; turn: R
# Iter: 2349 ; paint: . ; turn: R
# Iter: 2350 ; paint: . ; turn: R
# Iter: 2351 ; paint: . ; turn: R
# Iter: 2352 ; paint: . ; turn: R
# Iter: 2353 ; paint: . ; turn: R
# Iter: 2354 ; paint: . ; turn: R
# Iter: 2355 ; paint: . ; turn: R
# Iter: 2356 ; paint: . ; turn: R
# Iter: 2357 ; paint: . ; turn: R
# Iter: 2358 ; paint: . ; turn: R
# Iter: 2359 ; paint: . ; turn: R
# Iter: 2360 ; paint: . ; turn: R
# Iter: 2361 ; paint: . ; turn: R
# Iter: 2362 ; paint: . ; turn: R
# Iter: 2363 ; paint: . ; turn: R
# Iter: 2364 ; paint: . ; turn: R
# Iter: 2365 ; paint: . ; turn: R
# Iter: 2366 ; paint: . ; turn: R
# Iter: 2367 ; paint: . ; turn: R
# Iter: 2368 ; paint: . ; turn: R
# Iter: 2369 ; paint: . ; turn: R
# Iter: 2370 ; paint: . ; turn: R
# Iter: 2371 ; paint: . ; turn: R
# Iter: 2372 ; paint: . ; turn: R
# Iter: 2373 ; paint: . ; turn: R
# Iter: 2374 ; paint: . ; turn: R
# Iter: 2375 ; paint: . ; turn: R
# Iter: 2376 ; paint: . ; turn: R
# Iter: 2377 ; paint: . ; turn: R
# Iter: 2378 ; paint: . ; turn: R
# Iter: 2379 ; paint: . ; turn: R
# Iter: 2380 ; paint: . ; turn: R
# Iter: 2381 ; paint: . ; turn: R
# Iter: 2382 ; paint: . ; turn: R
# Iter: 2383 ; paint: . ; turn: R
# Iter: 2384 ; paint: . ; turn: R
# Iter: 2385 ; paint: . ; turn: R
# Iter: 2386 ; paint: . ; turn: R
# Iter: 2387 ; paint: . ; turn: R
# Iter: 2388 ; paint: . ; turn: R
# Iter: 2389 ; paint: . ; turn: R
# Iter: 2390 ; paint: . ; turn: R
# Iter: 2391 ; paint: . ; turn: R
# Iter: 2392 ; paint: . ; turn: R
# Iter: 2393 ; paint: . ; turn: R
# Iter: 2394 ; paint: . ; turn: R
# Iter: 2395 ; paint: . ; turn: R
# Iter: 2396 ; paint: . ; turn: R
# Iter: 2397 ; paint: . ; turn: R
# Iter: 2398 ; paint: . ; turn: R
# Iter: 2399 ; paint: . ; turn: R
# Iter: 2400 ; paint: . ; turn: R
# Iter: 2401 ; paint: . ; turn: R
# Iter: 2402 ; paint: . ; turn: R
# Iter: 2403 ; paint: . ; turn: R
# Iter: 2404 ; paint: . ; turn: R
# Iter: 2405 ; paint: . ; turn: R
# Iter: 2406 ; paint: . ; turn: R
# Iter: 2407 ; paint: . ; turn: R
# Iter: 2408 ; paint: . ; turn: R
# Iter: 2409 ; paint: . ; turn: R
# Iter:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-770fbb29cf52> in <module>
#     119     paintOutput = '#' if paintOutput == 0 else '.'
#     120     turnOutput = 'L' if turnOutput == 0 else 'R'
# --> 121     print('Iter:', iter, '; paint:', paintOutput, '; turn:', turnOutput)
#     122
#     123     if paintOutput == '#':
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
activePanels
# Out:
# []

# %% [markdown]
# # --- Day 12: The N-Body Problem ---

# %%
puzzle = '''<x=-1, y=0, z=2>
<x=2, y=-10, z=-7>
<x=4, y=-8, z=8>
<x=3, y=5, z=-1>'''
puzzle = '''<x=-8, y=-10, z=0>
<x=5, y=5, z=10>
<x=2, y=-7, z=3>
<x=9, y=-8, z=-3>'''
with open('12.txt') as f: puzzle = f.read()

puzzle = puzzle.replace(' ', '').split('\n')
puzzle = [ moon[1:-1].split(',') for moon in puzzle ]
puzzle = [ [ int(coord[2:]) for coord in moon ] for moon in puzzle ]
puzzle

################################################################################
# PART 1

pos = [ moon.copy() for moon in puzzle ]
vel = [ [0, 0, 0] for moon in puzzle ]
pos, vel


for iter in range(1000):

    # calculate gravity
    for i in range(4):
        p1 = pos[i]
        for j in range(i + 1, 4):
            p2 = pos[j]

            for k in range(3):
                if p1[k] < p2[k]:
                    vel[i][k] += 1
                    vel[j][k] -= 1
                if p1[k] > p2[k]:
                    vel[i][k] -= 1
                    vel[j][k] += 1

    # apply velocity
    for i in range(4):
        for k in range(3):
            pos[i][k] += vel[i][k]



pos = [ sum([ abs(coord) for coord in moon ]) for moon in pos ]
vel = [ sum([ abs(coord) for coord in moon ]) for moon in vel ]
pos, vel

s = 0
for i in range(4):
    s += pos[i] * vel[i]
s
# Out:
# 8287

# %% [markdown]
# # --- Day 14: Space Stoichiometry ---

# %%
puzzle = '''10 ORE => 10 A
1 ORE => 1 B
7 A, 1 B => 1 C
7 A, 1 C => 1 D
7 A, 1 D => 1 E
7 A, 1 E => 1 FUEL''' # 31

puzzle = '''9 ORE => 2 A
8 ORE => 3 B
7 ORE => 5 C
3 A, 4 B => 1 AB
5 B, 7 C => 1 BC
4 C, 1 A => 1 CA
2 AB, 3 BC, 4 CA => 1 FUEL''' # 165

puzzle = '''157 ORE => 5 NZVS
165 ORE => 6 DCFZ
44 XJWVT, 5 KHKGT, 1 QDVJ, 29 NZVS, 9 GPVTF, 48 HKGWZ => 1 FUEL
12 HKGWZ, 1 GPVTF, 8 PSHF => 9 QDVJ
179 ORE => 7 PSHF
177 ORE => 5 HKGWZ
7 DCFZ, 7 PSHF => 2 XJWVT
165 ORE => 2 GPVTF
3 DCFZ, 7 NZVS, 5 HKGWZ, 10 PSHF => 8 KHKGT''' # 13312

# puzzle = '''2 VPVL, 7 FWMGM, 2 CXFTF, 11 MNCFX => 1 STKFG
# 17 NVRVD, 3 JNWZP => 8 VPVL
# 53 STKFG, 6 MNCFX, 46 VJHF, 81 HVMC, 68 CXFTF, 25 GNMV => 1 FUEL
# 22 VJHF, 37 MNCFX => 5 FWMGM
# 139 ORE => 4 NVRVD
# 144 ORE => 7 JNWZP
# 5 MNCFX, 7 RFSQX, 2 FWMGM, 2 VPVL, 19 CXFTF => 3 HVMC
# 5 VJHF, 7 MNCFX, 9 VPVL, 37 CXFTF => 6 GNMV
# 145 ORE => 6 MNCFX
# 1 NVRVD => 8 CXFTF
# 1 VJHF, 6 MNCFX => 4 RFSQX
# 176 ORE => 6 VJHF''' # 180697

# puzzle = '''171 ORE => 8 CNZTR
# 7 ZLQW, 3 BMBT, 9 XCVML, 26 XMNCP, 1 WPTQ, 2 MZWV, 1 RJRHP => 4 PLWSL
# 114 ORE => 4 BHXH
# 14 VRPVC => 6 BMBT
# 6 BHXH, 18 KTJDG, 12 WPTQ, 7 PLWSL, 31 FHTLT, 37 ZDVW => 1 FUEL
# 6 WPTQ, 2 BMBT, 8 ZLQW, 18 KTJDG, 1 XMNCP, 6 MZWV, 1 RJRHP => 6 FHTLT
# 15 XDBXC, 2 LTCX, 1 VRPVC => 6 ZLQW
# 13 WPTQ, 10 LTCX, 3 RJRHP, 14 XMNCP, 2 MZWV, 1 ZLQW => 1 ZDVW
# 5 BMBT => 4 WPTQ
# 189 ORE => 9 KTJDG
# 1 MZWV, 17 XDBXC, 3 XCVML => 2 XMNCP
# 12 VRPVC, 27 CNZTR => 2 XDBXC
# 15 KTJDG, 12 BHXH => 5 XCVML
# 3 BHXH, 2 VRPVC => 7 MZWV
# 121 ORE => 7 VRPVC
# 7 XCVML => 6 RJRHP
# 5 BHXH, 4 VRPVC => 5 LTCX''' # 2210736

# with open('14.txt') as f: puzzle = f.read()


puzzle = puzzle.replace(', ', ' ').replace(' => ', ' ')
puzzle = puzzle.split('\n')
puzzle = [ line.split(' ') for line in puzzle ]
puzzle

################################################################################
# PART 1

#
requirements = {}
for i, line in enumerate(puzzle):
    assert len(line) % 2 == 0

    chem = line[-1]
    reqs = { line[j + 1] : int(line[j]) for j in range(0, len(line) - 2, 2) }
    requirements[chem] = { 'producing' : int(line[-2]), 'need' : reqs }

requirements


# layering
for chem in requirements: requirements[chem]['layer'] = None
requirements['FUEL']['layer'] = 0

l = 0
current_layer_chems = { 'FUEL' }
while True:

    # 
    # print('Current layer chems:', current_layer_chems)
    for c_l_chem in current_layer_chems:
        requirements[c_l_chem]['layer'] = l

    #
    next_layer_chems = set( n_chem for c_l_chem in current_layer_chems for n_chem in requirements[c_l_chem]['need'] )
    next_layer_chems = { n_l_chem for n_l_chem in next_layer_chems if n_l_chem != 'ORE' }
    # print('Next layer chems:', next_layer_chems)

    if len(next_layer_chems) == 0:
        break

    current_layer_chems = next_layer_chems.copy()
    l += 1

requirements


#
chems_buffer = { 'FUEL' : 1 }

L = max( requirements[chem]['layer'] for chem in requirements ) + 1
for l in range(L):

    layer_chems = [ chem for chem in requirements if requirements[chem]['layer'] == l ]
    # print('Layer chems:', layer_chems)

    for chem in layer_chems:
        assert chem in chems_buffer

        #
        q = chems_buffer[chem]
        p = requirements[chem]['producing']
        m = q // p
        if q % p != 0:
            m += 1
        assert q <= m * p

        #
        for n_chem in requirements[chem]['need']:
            if n_chem not in chems_buffer:
                chems_buffer[n_chem] = m * requirements[chem]['need'][n_chem]
            else:
                chems_buffer[n_chem] += m * requirements[chem]['need'][n_chem]

        del chems_buffer[chem]


assert len(chems_buffer) == 1 and 'ORE' in chems_buffer
chems_buffer['ORE']

################################################################################
# PART 2

chems_buffer = { 'FUEL' : 1 }
leftover = {}

L = max( requirements[chem]['layer'] for chem in requirements ) + 1
for l in range(L):

    layer_chems = [ chem for chem in requirements if requirements[chem]['layer'] == l ]
    # print('Layer chems:', layer_chems)

    for chem in layer_chems:
        assert chem in chems_buffer

        #
        q = chems_buffer[chem]
        p = requirements[chem]['producing']
        m = q // p
        if q % p != 0:
            m += 1
        assert q <= m * p

        #
        if q < m * p:
            leftover[chem] = m * p - q

        #
        for n_chem in requirements[chem]['need']:
            if n_chem not in chems_buffer:
                chems_buffer[n_chem] = m * requirements[chem]['need'][n_chem]
            else:
                chems_buffer[n_chem] += m * requirements[chem]['need'][n_chem]

        del chems_buffer[chem]


assert len(chems_buffer) == 1 and 'ORE' in chems_buffer
chems_buffer['ORE']


#
leftover
# cargo = 1000000000000
# fuel = cargo // chems_buffer['ORE']
# cargo = cargo % chems_buffer['ORE']

# for chem in leftover:
#     leftover[chem] *= fuel

# fuel, cargo, leftover
# Out:
# {'QDVJ': 8, 'KHKGT': 3, 'NZVS': 4, 'DCFZ': 5, 'PSHF': 3}

# %%
puzzle = puzzle.replace(',', '').split('\n')
for i, line in enumerate(puzzle):
    line = line.split(' => ')

    source = line[0].split(' ')
    for j in range(0, len(source), 2):
        source[j] = int(source[j])

    target = line[1].split(' ')
    assert len(target) == 2
    target[0] = int(target[0])

    puzzle[i] = { 'source' : source, 'target' : target }

puzzle

################################################################################
# PART 1

need = [ tx for tx in puzzle if tx['target'] == [1, 'FUEL'] ]
assert len(need) == 1
need = need[0]['source']
need
print(need)


#
from math import ceil

i = 0
while True:

    assert len(need) % 2 == 0
    quantity, material = need[i : i + 2]
    
    new = [ tx for tx in puzzle if tx['target'][1] == material ]
    assert len(new) == 1
    new = new[0]

    if 'ORE' in new['source']:
        i += 2
        if i >= len(need):
            break
        continue

    multiplier = quantity / new['target'][0]
    for j in range(0, len(new['source']), 2):
        new['source'][j] *= multiplier

    need = need[:i] + need[i + 2 :] + new['source']

    tmp = {}
    for j in range(0, len(need), 2):
        quantity, material = need[j : j + 2]
        if material not in tmp:
            tmp[material] = quantity
        else:
            tmp[material] += quantity
    
    need = []
    for material in tmp:
        need.append(tmp[material])
        need.append(material)
    print(need)


#



s = 0
for i in range(0, len(need), 2):
    quantity, material = need[i : i + 2]
    ore = [ tx for tx in puzzle if tx['target'][1] == material ]
    ore = ore[0]
    s += ore['source'][0] * ceil(quantity / ore['target'][0])
s
# Out:
# [53, 'STKFG', 6, 'MNCFX', 46, 'VJHF', 81, 'HVMC', 68, 'CXFTF', 25, 'GNMV']
# [589.0, 'MNCFX', 46, 'VJHF', 81, 'HVMC', 174.0, 'CXFTF', 25, 'GNMV', 106.0, 'VPVL', 371.0, 'FWMGM']
# [724.0, 'MNCFX', 46, 'VJHF', 687.0, 'CXFTF', 25, 'GNMV', 160.0, 'VPVL', 425.0, 'FWMGM', 189.0, 'RFSQX']
# [724.0, 'MNCFX', 46, 'VJHF', 25, 'GNMV', 160.0, 'VPVL', 425.0, 'FWMGM', 189.0, 'RFSQX', 85.875, 'NVRVD']
# [753.1666666666666, 'MNCFX', 66.83333333333334, 'VJHF', 197.5, 'VPVL', 425.0, 'FWMGM', 189.0, 'RFSQX', 85.875, 'NVRVD', 154.16666666666669, 'CXFTF']
# [753.1666666666666, 'MNCFX', 66.83333333333334, 'VJHF', 425.0, 'FWMGM', 189.0, 'RFSQX', 505.5625, 'NVRVD', 154.16666666666669, 'CXFTF', 74.0625, 'JNWZP']
# [3898.1666666666665, 'MNCFX', 1936.8333333333333, 'VJHF', 189.0, 'RFSQX', 505.5625, 'NVRVD', 154.16666666666669, 'CXFTF', 74.0625, 'JNWZP']
# [4181.666666666666, 'MNCFX', 1984.0833333333333, 'VJHF', 505.5625, 'NVRVD', 154.16666666666669, 'CXFTF', 74.0625, 'JNWZP']
# [4181.666666666666, 'MNCFX', 1984.0833333333333, 'VJHF', 2160.4453125, 'NVRVD', 74.0625, 'JNWZP']
# 236104

# %% [markdown]
# # --- Day 20: Donut Maze ---

# %%
puzzle = '''         A           
         A           
  #######.#########  
  #######.........#  
  #######.#######.#  
  #######.#######.#  
  #######.#######.#  
  #####  B    ###.#  
BC...##  C    ###.#  
  ##.##       ###.#  
  ##...DE  F  ###.#  
  #####    G  ###.#  
  #########.#####.#  
DE..#######...###.#  
  #.#########.###.#  
FG..#########.....#  
  ###########.#####  
             Z       
             Z       '''

puzzle = '''                   A               
                   A               
  #################.#############  
  #.#...#...................#.#.#  
  #.#.#.###.###.###.#########.#.#  
  #.#.#.......#...#.....#.#.#...#  
  #.#########.###.#####.#.#.###.#  
  #.............#.#.....#.......#  
  ###.###########.###.#####.#.#.#  
  #.....#        A   C    #.#.#.#  
  #######        S   P    #####.#  
  #.#...#                 #......VT
  #.#.#.#                 #.#####  
  #...#.#               YN....#.#  
  #.###.#                 #####.#  
DI....#.#                 #.....#  
  #####.#                 #.###.#  
ZZ......#               QG....#..AS
  ###.###                 #######  
JO..#.#.#                 #.....#  
  #.#.#.#                 ###.#.#  
  #...#..DI             BU....#..LF
  #####.#                 #.#####  
YN......#               VT..#....QG
  #.###.#                 #.###.#  
  #.#...#                 #.....#  
  ###.###    J L     J    #.#.###  
  #.....#    O F     P    #.#...#  
  #.###.#####.#.#####.#####.###.#  
  #...#.#.#...#.....#.....#.#...#  
  #.#####.###.###.#.#.#########.#  
  #...#.#.....#...#.#.#.#.....#.#  
  #.###.#####.###.###.#.#.#######  
  #.#.........#...#.............#  
  #########.###.###.#############  
           B   J   C               
           U   P   P               '''

with open('20.txt') as f: puzzle = f.read()

puzzle = puzzle.split('\n')
puzzle = list(map(list, puzzle))
# for row in puzzle: print(row)

################################################################################
# PART 1

R = len(puzzle)
C = len(puzzle[0])

graph = {}
portals = {}

for r in range(R):
    for c in range(C):

        tile = puzzle[r][c]
        if tile == '.':

            graph[ (r, c) ] = []

            neighbours = [ (r - 1, c), (r + 1, c), (r, c + 1), (r, c - 1) ]
            neighbours = [ n for n in neighbours if puzzle[ n[0] ][ n[1] ] != '#' ] # any which are not wall

            while len(neighbours) != 0:

                n = neighbours.pop()

                if puzzle[ n[0] ][ n[1] ] == '.': # open passage
                    graph[ (r, c) ].append(n)

                else: # a portal
                    d = (n[0] - r, n[1] - c)
                    
                    # check next char in direction => get portal name
                    if d == (-1, 0):
                        p = puzzle[ n[0] ][ n[1] ] + puzzle[ n[0] - 1 ][ n[1] ]
                    elif d == (1, 0):
                        p = puzzle[ n[0] ][ n[1] ] + puzzle[ n[0] + 1 ][ n[1] ]
                    elif d == (0, 1):
                        p = puzzle[ n[0] ][ n[1] ] + puzzle[ n[0] ][ n[1] + 1 ]
                    else:
                        assert d == (0, -1)
                        p = puzzle[ n[0] ][ n[1] ] + puzzle[ n[0] ][ n[1] - 1 ]

                    p = sorted(p)
                    p = ''.join(p)
                    
                    # connect portals
                    if p not in portals:
                        portals[p] = [ (r, c) ]
                    else:
                        portals[p].append( (r, c) )

# connect portals in graph
for p in portals:
    if len(portals[p]) == 2:
        graph[ portals[p][0] ].append( portals[p][1] )
        graph[ portals[p][1] ].append( portals[p][0] )

graph


#
start = portals['AA'][0]
end = portals['ZZ'][0]
distances = { node : 1000000 for node in graph }
distances[start] = 0
distances

buffer = [ start ]
while len(buffer) != 0:

    curr = buffer.pop()
    neighbours = graph[curr]

    for next in neighbours:
        if distances[curr] + 1 < distances[next]:
            buffer.append(next)
            distances[next] = distances[curr] + 1

distances[end]
# Out:
# 522
